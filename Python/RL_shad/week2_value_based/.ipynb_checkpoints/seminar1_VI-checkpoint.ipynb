# %% [markdown]
# ### Markov decision process
#
# This week's methods are all built to solve __M__arkov __D__ecision __P__rocesses. In the broadest sense, an MDP is defined by how it changes states and how rewards are computed.
#
# State transition is defined by $P(s' |s,a)$ - how likely are you to end at state $s'$ if you take action $a$ from state $s$. Now there's more than one way to define rewards, but we'll use $r(s,a,s')$ function for convenience.
#
# _This notebook is inspired by the awesome_ [CS294](https://github.com/berkeleydeeprlcourse/homework/tree/master/sp17_hw/hw2) _by Berkeley_

# %% [markdown]
# For starters, let's define a simple MDP from this picture:
# <img src='https://s17.postimg.org/mawroys8f/750px-_Markov_Decision_Process_example.png' width=300px>
# _img by MistWiz (Own work) [Public domain], via Wikimedia Commons_

# %%
transition_probs = {
  's0':{
    'a0': {'s0': 0.5, 's2': 0.5},
    'a1': {'s2': 1}
  },
  's1':{
    'a0': {'s0': 0.7, 's1': 0.1, 's2': 0.2},
    'a1': {'s1': 0.95, 's2': 0.05}
  },
  's2':{
    'a0': {'s0': 0.4, 's1': 0.6},
    'a1': {'s0': 0.3, 's1': 0.3, 's2':0.4}
  }
}
rewards = {
  's1': {'a0': {'s0': +5}},
  's2': {'a1': {'s0': -1}}
}

from mdp import MDP
mdp = MDP(transition_probs, rewards, initial_state='s0')

# %% [markdown]
# We can now use MDP just as any other gym environment:

# %%
print('initial state =', mdp.reset())
next_state, reward, done, info = mdp.step('a1')
print('next_state = %s, reward = %s, done = %s' % (next_state, reward, done))
# Out:
# initial state = s0
# next_state = s2, reward = 0.0, done = False

# %% [markdown]
# but it also has other methods that you'll need for Value Iteration

# %%
print("mdp.get_all_states =", mdp.get_all_states())
print("mdp.get_possible_actions('s1') = ", mdp.get_possible_actions('s1'))
print("mdp.get_next_states('s1', 'a0') = ", mdp.get_next_states('s1', 'a0'))
print("mdp.get_reward('s1', 'a0', 's0') = ", mdp.get_reward('s1', 'a0', 's0'))
print("mdp.get_transition_prob('s1', 'a0', 's0') = ", mdp.get_transition_prob('s1', 'a0', 's0'))
# Out:
# mdp.get_all_states = ('s0', 's1', 's2')
# mdp.get_possible_actions('s1') =  ('a0', 'a1')
# mdp.get_next_states('s1', 'a0') =  {'s0': 0.7, 's1': 0.1, 's2': 0.2}
# mdp.get_reward('s1', 'a0', 's0') =  5
# mdp.get_transition_prob('s1', 'a0', 's0') =  0.7

# %% [markdown]
# ### Value Iteration
#
# Now let's build something to solve this MDP. The simplest algorithm so far is __V__alue __I__teration
#
# Here's the pseudo-code for VI:
#
# ---
#
# `1.` Initialize $V^{(0)}(s)=0$, for all $s$
#
# `2.` For $i=0, 1, 2, \dots$
#
# `3.` $ \quad V_{(i+1)}(s) = \max_a \sum_{s'} P(s' | s,a) \cdot [ r(s,a,s') + \gamma V_{i}(s')]$, for all $s$
#
# ---

# %% [markdown]
# First, let's write a function to compute the state-action value function $Q^{\pi}$, defined as follows
#
# $$Q_i(s, a) = \sum_{s'} P(s' | s,a) \cdot [ r(s,a,s') + \gamma V_{i}(s')]$$

# %%
def get_action_value(mdp, state_values, state, action, gamma):
    """ Computes Q(s,a) as in formula above """
    
    ###YOUR CODE HERE
    q_value = 0
    for next_state in mdp.get_all_states() :
       
        q_value = q_value + mdp.get_transition_prob(state, action, next_state) * (mdp.get_reward(state, action, next_state) + gamma * state_values[next_state])
    return q_value#<YOUR CODE>

# %%
import numpy as np
test_Vs = {s : i for i, s in enumerate(sorted(mdp.get_all_states()))}
print(test_Vs)
assert np.allclose(get_action_value(mdp, test_Vs, 's2', 'a1', 0.9), 0.69)
assert np.allclose(get_action_value(mdp, test_Vs, 's1', 'a0', 0.9), 3.95)
# Out:
# {'s0': 0, 's1': 1, 's2': 2}

# %% [markdown]
# Using $Q(s,a)$ we can now define the "next" V(s) for value iteration.
#  $$V_{(i+1)}(s) = \max_a \sum_{s'} P(s' | s,a) \cdot [ r(s,a,s') + \gamma V_{i}(s')] = \max_a Q_i(s,a)$$

# %%
def get_new_state_value(mdp, state_values, state, gamma):
    """ Computes next V(s) as in formula above. Please do not change state_values in process. """
    if mdp.is_terminal(state): return 0
    max_q_value = -np.inf
    for action in mdp.get_possible_actions(state):
        q_value = get_action_value(mdp, state_values, state, action, gamma)
        #for next_state in mdp.get_all_states():
        #    q_value = (
        #        q_value + mdp.get_transition_prob(state, action, next_state) *
        #        (mdp.get_reward(state, action, next_state) + gamma * state_values[next_state])
        #    )
        if q_value > max_q_value:
            max_q_value = q_value
        
    ### <YOUR CODE>
    return  max_q_value

# %%
test_Vs_copy = dict(test_Vs)
assert np.allclose(get_new_state_value(mdp, test_Vs, 's0', 0.9), 1.8)
assert np.allclose(get_new_state_value(mdp, test_Vs, 's2', 0.9), 0.69)
assert test_Vs == test_Vs_copy, "please do not change state_values in get_new_state_value"

# %% [markdown]
# Finally, let's combine everything we wrote into a working value iteration algo.

# %%
# parameters
gamma = 0.9            # discount for MDP
num_iter = 100         # maximum iterations, excluding initialization
min_difference = 0.001 # stop VI if new values are this close to old values (or closer)

# initialize V(s)
state_values = {s : 0 for s in mdp.get_all_states()}


for i in range(num_iter):
    
    # Compute new state values using the functions you defined above.
    # It must be a dict {state : float V_new(state)}
    new_state_values = {state : get_new_state_value(mdp, state_values, state, gamma) for state in mdp.get_all_states()}#<YOUR CODE HERE>
    
    assert isinstance(new_state_values, dict)
    
    # Compute difference
    diff = max(abs(new_state_values[s] - state_values[s]) for s in mdp.get_all_states())
    print("iter %4i   |   diff: %6.5f   |   "%(i, diff), end="")
    print('   '.join("V(%s) = %.3f"%(s, v) for s,v in state_values.items()), end='\n\n')
    state_values = new_state_values
    
    if diff < min_difference:
        print("Terminated"); break

# %%
print("Final state values:", state_values)

assert abs(state_values['s0'] - 8.032)  < 0.01
assert abs(state_values['s1'] - 11.169) < 0.01
assert abs(state_values['s2'] - 8.921)  < 0.01

# %% [markdown]
# Now let's use those $V^{*}(s)$ to find optimal actions in each state
#
#  $$\pi^*(s) = argmax_a \sum_{s'} P(s' | s,a) \cdot [ r(s,a,s') + \gamma V_{i}(s')] = argmax_a Q_i(s,a)$$
#
# The only difference vs V(s) is that here we take not max but argmax: find action such with maximum Q(s,a).

# %%
def get_optimal_action(mdp, state_values, state, gamma=0.9):
    """ Finds optimal action using formula above. """
    if mdp.is_terminal(state): return None
    argmax_q_value = 0
    max_q_value = -np.inf
    actions = mdp.get_possible_actions(state)
    #for i, action in enumerate(actions):
    #    q_value = get_action_value(mdp, state_values, state, action, gamma)
    #    if q_value > max_q_value:
    #        argmax_q_value = i 
    q_values = [get_action_value(mdp, state_values, state, action, gamma) for action in actions]
    ### <YOUR CODE HERE>
    return actions[np.argmax(q_values)]

# %%
assert get_optimal_action(mdp, state_values, 's0', gamma) == 'a1'
assert get_optimal_action(mdp, state_values, 's1', gamma) == 'a0'
assert get_optimal_action(mdp, state_values, 's2', gamma) == 'a0'

# %%
# Measure agent's average reward

s = mdp.reset()
rewards = []
for _ in range(10000):
    s, r, done, _ = mdp.step(get_optimal_action(mdp, state_values, s, gamma))
    rewards.append(r)
    
print("average reward: ", np.mean(rewards))

assert(0.85 < np.mean(rewards) < 1.0)

# %% [markdown]
# ### Frozen lake

# %%
from mdp import FrozenLakeEnv
mdp = FrozenLakeEnv(slip_chance=0)

mdp.render()
# Out:
# *FFF
# FHFH
# FFFH
# HFFG

# %%
state_values = state_values or {s : 0 for s in mdp.get_all_states()}
state_values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a5c1774fefe8> in <module>()
# ----> 1 state_values = state_values or {s : 0 for s in mdp.get_all_states()}
#       2 state_values
#
# NameError: name 'state_values' is not defined

# %%
def value_iteration(mdp, state_values=None, gamma = 0.9, num_iter = 1000, min_difference = 1e-5):
    """ performs num_iter value iteration steps starting from state_values. Same as before but in a function """
    state_values = state_values or {s : 0 for s in mdp.get_all_states()}
    for i in range(num_iter):

        # Compute new state values using the functions you defined above. It must be a dict {state : new_V(state)}
        new_state_values = {state : get_new_state_value(mdp, state_values, state, gamma) for state in mdp.get_all_states()}#mycode
        
        assert isinstance(new_state_values, dict)
        # Compute difference
        diff =  max(abs(new_state_values[s] - state_values[s]) for s in mdp.get_all_states())
        
        print("iter %4i   |   diff: %6.5f   |   V(start): %.3f "%(i, diff, new_state_values[mdp._initial_state]))
        
        state_values = new_state_values
        if diff < min_difference:
            break
            
    return state_values

# %%
state_values = value_iteration(mdp)

# %%
s = mdp.reset()
mdp.render()
for t in range(100):
    a = get_optimal_action(mdp, state_values, s, gamma)
    print(a, end='\n\n')
    s, r, done, _ = mdp.step(a)
    mdp.render()
    if done: break

# %% [markdown]
# ### Let's visualize!
#
# It's usually interesting to see what your algorithm actually learned under the hood. To do so, we'll plot state value functions and optimal actions at each VI step.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def draw_policy(mdp, state_values):
    plt.figure(figsize=(3,3))
    h,w = mdp.desc.shape
    states = sorted(mdp.get_all_states())
    V = np.array([state_values[s] for s in states])
    Pi = {s: get_optimal_action(mdp, state_values, s, gamma) for s in states}
    plt.imshow(V.reshape(w,h), cmap='gray', interpolation='none', clim=(0,1))
    ax = plt.gca()
    ax.set_xticks(np.arange(h)-.5)
    ax.set_yticks(np.arange(w)-.5)
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    Y, X = np.mgrid[0:4, 0:4]
    a2uv = {'left': (-1, 0), 'down':(0, -1), 'right':(1,0), 'up':(-1, 0)}
    for y in range(h):
        for x in range(w):
            plt.text(x, y, str(mdp.desc[y,x].item()),
                     color='g', size=12,  verticalalignment='center',
                     horizontalalignment='center', fontweight='bold')
            a = Pi[y, x]
            if a is None: continue
            u, v = a2uv[a]
            plt.arrow(x, y,u*.3, -v*.3, color='m', head_width=0.1, head_length=0.1) 
    plt.grid(color='b', lw=2, ls='-')
    plt.show()

# %%
state_values = {s : 0 for s in mdp.get_all_states()}

for i in range(10):
    print("after iteration %i"%i)
    state_values = value_iteration(mdp, state_values, num_iter=1)
    draw_policy(mdp, state_values)
# please ignore iter 0 at each step

# %%
from IPython.display import clear_output
from time import sleep
mdp = FrozenLakeEnv(map_name='8x8',slip_chance=0.1)
state_values = {s : 0 for s in mdp.get_all_states()}

for i in range(30):
    clear_output(True)
    print("after iteration %i"%i)
    state_values = value_iteration(mdp, state_values, num_iter=1)
    draw_policy(mdp, state_values)
    sleep(0.5)
# please ignore iter 0 at each step

# %% [markdown]
# Massive tests

# %%
mdp = FrozenLakeEnv(slip_chance=0)
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(get_optimal_action(mdp, state_values, s, gamma))
        rewards.append(r)
        if done: break
    total_rewards.append(np.sum(rewards))
    
print("average reward: ", np.mean(total_rewards))
assert(1.0 <= np.mean(total_rewards) <= 1.0)
print("Well done!")

# %%
# Measure agent's average reward
mdp = FrozenLakeEnv(slip_chance=0.1)
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(get_optimal_action(mdp, state_values, s, gamma))
        rewards.append(r)
        if done: break
    total_rewards.append(np.sum(rewards))
    
print("average reward: ", np.mean(total_rewards))
assert(0.8 <= np.mean(total_rewards) <= 0.95)
print("Well done!")

# %%
# Measure agent's average reward
mdp = FrozenLakeEnv(slip_chance=0.25)
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(get_optimal_action(mdp, state_values, s, gamma))
        rewards.append(r)
        if done: break
    total_rewards.append(np.sum(rewards))
    
print("average reward: ", np.mean(total_rewards))
assert(0.6 <= np.mean(total_rewards) <= 0.7)
print("Well done!")

# %%
# Measure agent's average reward
mdp = FrozenLakeEnv(slip_chance=0.2, map_name='8x8')
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(get_optimal_action(mdp, state_values, s, gamma))
        rewards.append(r)
        if done: break
    total_rewards.append(np.sum(rewards))
    
print("average reward: ", np.mean(total_rewards))
assert(0.6 <= np.mean(total_rewards) <= 0.8)
print("Well done!")

# %% [markdown]
# ## Bonus area

# %% [markdown]
# ### Bonus 1 - find an MDP for which value iteration takes long to converge  (2+ pts)
#
# When we ran value iteration on the small frozen lake problem, the last iteration where an action changed was iteration 6--i.e., value iteration computed the optimal policy at iteration 6. Are there any guarantees regarding how many iterations it'll take value iteration to compute the optimal policy? There are no such guarantees without additional assumptions--we can construct the MDP in such a way that the greedy policy will change after arbitrarily many iterations.
#
# Your task: define an MDP with at most 3 states and 2 actions, such that when you run value iteration, the optimal action changes at iteration >= 50. Use discount=0.95. (However, note that the discount doesn't matter here--you can construct an appropriate MDP with any discount.)
#
# Note: value function must change at least once after iteration >=50, not necessarily change on every iteration till >=50.

# %%
transition_probs = {
  's0':{
    'a0': {'s0': 0.5, 's2': 0.5},
    'a1': {'s2': 1}
  },
  's1':{
    'a0': {'s0': 0.7, 's1': 0.1, 's2': 0.2},
    'a1': {'s1': 0.95, 's2': 0.05}
  },
  's2':{
    'a0': {'s0': 0.4, 's1': 0.6},
    'a1': {'s0': 0.3, 's1': 0.3, 's2':0.4}
  }
}
rewards = {
  's1': {'a0': {'s0': +5}},
  's2': {'a1': {'s0': -1}}
}

from mdp import MDP
mdp = MDP(transition_probs, rewards)

# %%
from matplotlib import pyplot as plt

# %%
transition_probs = {
  's0':{
    'a0': {'s0': 1 - 0.00000005, 's1': 0.00000005}
  },
  's1':{
    'a1': {'s1': 1}
  }
}
rewards = {
  's0': {'a0': {'s0': 1}},
  's1': {'a1': {'s1': 100}},
}

from mdp import MDP
mdp = MDP(transition_probs, rewards)

# %%
def value_iteration(mdp, state_values=None, gamma = 0.95, num_iter = 1000, min_difference = 1e-5):
    """ performs num_iter value iteration steps starting from state_values. Same as before but in a function """
    state_values = state_values or {s : 0 for s in mdp.get_all_states()}
    differ = []
    for i in range(num_iter):

        # Compute new state values using the functions you defined above. It must be a dict {state : new_V(state)}
        new_state_values = {state : get_new_state_value(mdp, state_values, state, gamma) for state in mdp.get_all_states()}#mycode
        
        assert isinstance(new_state_values, dict)
        # Compute difference
        diff =  max(abs(new_state_values[s] - state_values[s]) for s in mdp.get_all_states())
        differ.append(diff)
        print("iter %4i   |   diff: %6.5f   |   V(start): %.3f "%(i, diff, new_state_values['s0']))
        
        state_values = new_state_values
        if diff < min_difference:
            break
            
    return state_values, differ

# %%
start = mdp.reset()
start

# %%
state_values, diff = value_iteration(mdp)

# %%
state_values

# %%
plt.plot(diff)

# %%
state_values

# %% [markdown]
# ### Bonus 2 - Policy Iteration (3+ points)
#
# Let's implement exact policy iteration (PI), which has the following pseudocode:
#
# ---
# Initialize $\pi_0$   `// random or fixed action`
#
# For $n=0, 1, 2, \dots$
# - Compute the state-value function $V^{\pi_{n}}$
# - Using $V^{\pi_{n}}$, compute the state-action-value function $Q^{\pi_{n}}$
# - Compute new policy $\pi_{n+1}(s) = \operatorname*{argmax}_a Q^{\pi_{n}}(s,a)$
# ---
#
# Unlike VI, policy iteration has to maintain a policy - chosen actions from all states - and estimate $V^{\pi_{n}}$ based on this policy. It only changes policy once values converged.
#
#
# Below are a few helpers that you may or may not use in your implementation.

# %%
transition_probs = {
  's0':{
    'a0': {'s0': 0.5, 's2': 0.5},
    'a1': {'s2': 1}
  },
  's1':{
    'a0': {'s0': 0.7, 's1': 0.1, 's2': 0.2},
    'a1': {'s1': 0.95, 's2': 0.05}
  },
  's2':{
    'a0': {'s0': 0.4, 's1': 0.6},
    'a1': {'s0': 0.3, 's1': 0.3, 's2':0.4}
  }
}
rewards = {
  's1': {'a0': {'s0': +5}},
  's2': {'a1': {'s0': -1}}
}

from mdp import MDP
mdp = MDP(transition_probs, rewards, initial_state='s0')

# %% [markdown]
# Let's write a function called `compute_vpi` that computes the state-value function $V^{\pi}$ for an arbitrary policy $\pi$.
#
# Unlike VI, this time you must find the exact solution, not just a single iteration.
#
# Recall that $V^{\pi}$ satisfies the following linear equation:
# $$V^{\pi}(s) = \sum_{s'} P(s,\pi(s),s')[ R(s,\pi(s),s') + \gamma V^{\pi}(s')]$$
#
# You'll have to solve a linear system in your code. (Find an exact solution, e.g., with `np.linalg.solve`.)

# %%
def compute_vpi(mdp, policy, gamma):
    """
    Computes updated V^pi(s) FOR ALL STATES under given policy.
    :param state_values: a dict of previous state values {state : V(s)}
    :param policy: a dict of currently chosen actions {s : a}
    :returns: a dict {state : V^pi(state) for all states}
    """
    # YOUR CODE HERE
    states = mdp.get_all_states()
    len_s = len(states)
    V = np.zeros(len_s * len_s).reshape(len_s, len_s)
    b = np.zeros(len_s)
    for i, state in enumerate(states):
        for j, next_state in enumerate(states):
            b[i] = (
                b[i] + mdp.get_transition_prob(state, policy[state], next_state) * 
                (mdp.get_reward(state, policy[state], next_state))
            )
            V[i, j] = (
                V[i, j] + mdp.get_transition_prob(state, policy[state], next_state) * gamma
            )
            if i == j:
                V[i, j] = V[i, j] - 1
                
    solve = np.linalg.solve(V, -b)
    #print(V, -b, solve)
    return dict(zip(states, solve))

# %%
gamma = 0.9

# %%
test_policy = {s: np.random.choice(mdp.get_possible_actions(s)) for s in mdp.get_all_states()}
new_vpi = compute_vpi(mdp, test_policy, gamma)

print(new_vpi)

assert type(new_vpi) is dict, "compute_vpi must return a dict {state : V^pi(state) for all states}"
# Out:
# {'s0': 3.78994861511468, 's1': 7.3029201654342675, 's2': 4.211054016794089}

# %% [markdown]
# Once we've got new state values, it's time to update our policy.

# %%
def compute_new_policy(mdp, vpi, gamma):
    """
    Computes new policy as argmax of state values
    :param vpi: a dict {state : V^pi(state) for all states}
    :returns: a dict {state : optimal action for all states}
    """
    #<YOUR CODE>
    states = mdp.get_all_states()
    best_actions = []
    for state in states:
        actions = mdp.get_possible_actions(state)
        q_values = [get_action_value(mdp, vpi, state, action, gamma) for action in actions]
        best_actions.append(actions[np.argmax(q_values)])
    ### <YOUR CODE HERE>
    policy = dict(zip(states, best_actions))
    return policy

# %%
new_policy = compute_new_policy(mdp, new_vpi, gamma)

print(new_policy)

assert type(new_policy) is dict, "compute_new_policy must return a dict {state : optimal action for all states}"
# Out:
# {'s0': 'a1', 's1': 'a0', 's2': 'a0'}

# %% [markdown]
# __Main loop__

# %%
def get_rand_policy(state):
    try:
        return np.random.choice(mdp.get_possible_actions(state))
    except:
        return

# %%
def policy_iteration(mdp, policy=None, gamma = 0.9, num_iter = 50, min_difference = 1e-5):
    """ performs num_iter value iteration steps starting from state_values. Same as before but in a function """
    #states = list(set(mdp.get_all_states()) - {(1,1), (1,3), (3,0), (2,3), (3,3)})
    if policy is None:
        policy = {s: np.random.choice(mdp.get_possible_actions(s)) for s in mdp.get_all_states()}
        #new_vpi = compute_vpi(mdp, test_policy, gamma)
        #policy = {s: get_rand_policy(s) for s in states}
    for i in range(num_iter):
        #print(compute_vpi(mdp, policy, gamma))
        #print(compute_vpi(mdp, policy, gamma))
        new_vpi = compute_vpi(mdp, policy, gamma)
        print(new_vpi)
        # Compute new state values using the functions you defined above. It must be a dict {state : new_V(state)}
        new_policy = compute_new_policy(mdp,new_vpi, gamma)
        
        assert isinstance(new_policy, dict)
        # Compute difference
        #diff =  max(abs(new_policy[s] - policy[s]) for s in mdp.get_all_states())
        diff =  np.sum((new_policy[s] == policy[s]) for s in mdp.get_all_states())
        print("iter %4i   |   diff: %6.5f   |   V(start): %.3s "%(i, diff, new_policy))
        
        policy = new_policy
        if diff < min_difference:
            break
            
    return state_values

# %%
mdp.render()
state_values = policy_iteration(mdp)
# Out:
# Currently at s0
# iter    0   |   diff: 3.00000   |   V(start): {'s
# iter    1   |   diff: 3.00000   |   V(start): {'s
# iter    2   |   diff: 3.00000   |   V(start): {'s
# iter    3   |   diff: 3.00000   |   V(start): {'s
# iter    4   |   diff: 3.00000   |   V(start): {'s
# iter    5   |   diff: 3.00000   |   V(start): {'s
# iter    6   |   diff: 3.00000   |   V(start): {'s
# iter    7   |   diff: 3.00000   |   V(start): {'s
# iter    8   |   diff: 3.00000   |   V(start): {'s
# iter    9   |   diff: 3.00000   |   V(start): {'s
# iter   10   |   diff: 3.00000   |   V(start): {'s
# iter   11   |   diff: 3.00000   |   V(start): {'s
# iter   12   |   diff: 3.00000   |   V(start): {'s
# iter   13   |   diff: 3.00000   |   V(start): {'s
# iter   14   |   diff: 3.00000   |   V(start): {'s
# iter   15   |   diff: 3.00000   |   V(start): {'s
# iter   16   |   diff: 3.00000   |   V(start): {'s
# iter   17   |   diff: 3.00000   |   V(start): {'s
# iter   18   |   diff: 3.00000   |   V(start): {'s
# iter   19   |   diff: 3.00000   |   V(start): {'s
# iter   20   |   diff: 3.00000   |   V(start): {'s
# iter   21   |   diff: 3.00000   |   V(start): {'s
# iter   22   |   diff: 3.00000   |   V(start): {'s
# iter   23   |   diff: 3.00000   |   V(start): {'s
# iter   24   |   diff: 3.00000   |   V(start): {'s
# iter   25   |   diff: 3.00000   |   V(start): {'s
# iter   26   |   diff: 3.00000   |   V(start): {'s
# iter   27   |   diff: 3.00000   |   V(start): {'s
# iter   28   |   diff: 3.00000   |   V(start): {'s
# iter   29   |   diff: 3.00000   |   V(start): {'s
# iter   30   |   diff: 3.00000   |   V(start): {'s
# iter   31   |   diff: 3.00000   |   V(start): {'s
# iter   32   |   diff: 3.00000   |   V(start): {'s
# iter   33   |   diff: 3.00000   |   V(start): {'s
# iter   34   |   diff: 3.00000   |   V(start): {'s
# iter   35   |   diff: 3.00000   |   V(start): {'s
# iter   36   |   diff: 3.00000   |   V(start): {'s
# iter   37   |   diff: 3.00000   |   V(start): {'s
# iter   38   |   diff: 3.00000   |   V(start): {'s
# iter   39   |   diff: 3.00000   |   V(start): {'s
# iter   40   |   diff: 3.00000   |   V(start): {'s
# iter   41   |   diff: 3.00000   |   V(start): {'s
# iter   42   |   diff: 3.00000   |   V(start): {'s
# iter   43   |   diff: 3.00000   |   V(start): {'s
# iter   44   |   diff: 3.00000   |   V(start): {'s
# iter   45   |   diff: 3.00000   |   V(start): {'s
# iter   46   |   diff: 3.00000   |   V(start): {'s
# iter   47   |   diff: 3.00000   |   V(start): {'s
# iter   48   |   diff: 3.00000   |   V(start): {'s
# iter   49   |   diff: 3.00000   |   V(start): {'s
# iter   50   |   diff: 3.00000   |   V(start): {'s
# iter   51   |   diff: 3.00000   |   V(start): {'s
# iter   52   |   diff: 3.00000   |   V(start): {'s
# iter   53   |   diff: 3.00000   |   V(start): {'s
# iter   54   |   diff: 3.00000   |   V(start): {'s
# iter   55   |   diff: 3.00000   |   V(start): {'s
# iter   56   |   diff: 3.00000   |   V(start): {'s
# iter   57   |   diff: 3.00000   |   V(start): {'s
# iter   58   |   diff: 3.00000   |   V(start): {'s
# iter   59   |   diff: 3.00000   |   V(start): {'s
# iter   60   |   diff: 3.00000   |   V(start): {'s
# iter   61   |   diff: 3.00000   |   V(start): {'s
# iter   62   |   diff: 3.00000   |   V(start): {'s
# iter   63   |   diff: 3.00000   |   V(start): {'s
# iter   64   |   diff: 3.00000   |   V(start): {'s
# iter   65   |   diff: 3.00000   |   V(start): {'s
# iter   66   |   diff: 3.00000   |   V(start): {'s
# iter   67   |   diff: 3.00000   |   V(start): {'s
# iter   68   |   diff: 3.00000   |   V(start): {'s
# iter   69   |   diff: 3.00000   |   V(start): {'s
# iter   70   |   diff: 3.00000   |   V(start): {'s
# iter   71   |   diff: 3.00000   |   V(start): {'s
# iter   72   |   diff: 3.00000   |   V(start): {'s
# iter   73   |   diff: 3.00000   |   V(start): {'s
# iter   74   |   diff: 3.00000   |   V(start): {'s
# iter   75   |   diff: 3.00000   |   V(start): {'s
# iter   76   |   diff: 3.00000   |   V(start): {'s
# iter   77   |   diff: 3.00000   |   V(start): {'s
# iter   78   |   diff: 3.00000   |   V(start): {'s
# iter   79   |   diff: 3.00000   |   V(start): {'s
# iter   80   |   diff: 3.00000   |   V(start): {'s
# iter   81   |   diff: 3.00000   |   V(start): {'s
# iter   82   |   diff: 3.00000   |   V(start): {'s
# iter   83   |   diff: 3.00000   |   V(start): {'s
# iter   84   |   diff: 3.00000   |   V(start): {'s
# iter   85   |   diff: 3.00000   |   V(start): {'s
# iter   86   |   diff: 3.00000   |   V(start): {'s
# iter   87   |   diff: 3.00000   |   V(start): {'s
# iter   88   |   diff: 3.00000   |   V(start): {'s
# iter   89   |   diff: 3.00000   |   V(start): {'s
# iter   90   |   diff: 3.00000   |   V(start): {'s
# iter   91   |   diff: 3.00000   |   V(start): {'s
# iter   92   |   diff: 3.00000   |   V(start): {'s
# iter   93   |   diff: 3.00000   |   V(start): {'s
# iter   94   |   diff: 3.00000   |   V(start): {'s
# iter   95   |   diff: 3.00000   |   V(start): {'s
# iter   96   |   diff: 3.00000   |   V(start): {'s
# iter   97   |   diff: 3.00000   |   V(start): {'s
# iter   98   |   diff: 3.00000   |   V(start): {'s
# iter   99   |   diff: 3.00000   |   V(start): {'s
# iter  100   |   diff: 3.00000   |   V(start): {'s
# iter  101   |   diff: 3.00000   |   V(start): {'s
# iter  102   |   diff: 3.00000   |   V(start): {'s
# iter  103   |   diff: 3.00000   |   V(start): {'s
# iter  104   |   diff: 3.00000   |   V(start): {'s
# iter  105   |   diff: 3.00000   |   V(start): {'s
# iter  106   |   diff: 3.00000   |   V(start): {'s
# iter  107   |   diff: 3.00000   |   V(start): {'s
# iter  108   |   diff: 3.00000   |   V(start): {'s
# iter  109   |   diff: 3.00000   |   V(start): {'s
# iter  110   |   diff: 3.00000   |   V(start): {'s
# iter  111   |   diff: 3.00000   |   V(start): {'s
# iter  112   |   diff: 3.00000   |   V(start): {'s
# iter  113   |   diff: 3.00000   |   V(start): {'s
# iter  114   |   diff: 3.00000   |   V(start): {'s
# iter  115   |   diff: 3.00000   |   V(start): {'s
# iter  116   |   diff: 3.00000   |   V(start): {'s
# iter  117   |   diff: 3.00000   |   V(start): {'s
# iter  118   |   diff: 3.00000   |   V(start): {'s
# iter  119   |   diff: 3.00000   |   V(start): {'s
# iter  120   |   diff: 3.00000   |   V(start): {'s
# iter  121   |   diff: 3.00000   |   V(start): {'s
# iter  122   |   diff: 3.00000   |   V(start): {'s
# iter  123   |   diff: 3.00000   |   V(start): {'s
# iter  124   |   diff: 3.00000   |   V(start): {'s
# iter  125   |   diff: 3.00000   |   V(start): {'s
# iter  126   |   diff: 3.00000   |   V(start): {'s
# iter  127   |   diff: 3.00000   |   V(start): {'s
# iter  128   |   diff: 3.00000   |   V(start): {'s
# iter  129   |   diff: 3.00000   |   V(start): {'s
# iter  130   |   diff: 3.00000   |   V(start): {'s
# iter  131   |   diff: 3.00000   |   V(start): {'s
# iter  132   |   diff: 3.00000   |   V(start): {'s
# iter  133   |   diff: 3.00000   |   V(start): {'s
# iter  134   |   diff: 3.00000   |   V(start): {'s
# iter  135   |   diff: 3.00000   |   V(start): {'s
# iter  136   |   diff: 3.00000   |   V(start): {'s
# iter  137   |   diff: 3.00000   |   V(start): {'s
# iter  138   |   diff: 3.00000   |   V(start): {'s
# iter  139   |   diff: 3.00000   |   V(start): {'s
# iter  140   |   diff: 3.00000   |   V(start): {'s
# iter  141   |   diff: 3.00000   |   V(start): {'s
# iter  142   |   diff: 3.00000   |   V(start): {'s
# iter  143   |   diff: 3.00000   |   V(start): {'s
# iter  144   |   diff: 3.00000   |   V(start): {'s
# iter  145   |   diff: 3.00000   |   V(start): {'s
# iter  146   |   diff: 3.00000   |   V(start): {'s
# iter  147   |   diff: 3.00000   |   V(start): {'s
# iter  148   |   diff: 3.00000   |   V(start): {'s
# iter  149   |   diff: 3.00000   |   V(start): {'s
# iter  150   |   diff: 3.00000   |   V(start): {'s
# iter  151   |   diff: 3.00000   |   V(start): {'s
# iter  152   |   diff: 3.00000   |   V(start): {'s
# iter  153   |   diff: 3.00000   |   V(start): {'s
# iter  154   |   diff: 3.00000   |   V(start): {'s
# iter  155   |   diff: 3.00000   |   V(start): {'s
# iter  156   |   diff: 3.00000   |   V(start): {'s
# iter  157   |   diff: 3.00000   |   V(start): {'s
# iter  158   |   diff: 3.00000   |   V(start): {'s
# iter  159   |   diff: 3.00000   |   V(start): {'s
# iter  160   |   diff: 3.00000   |   V(start): {'s
# iter  161   |   diff: 3.00000   |   V(start): {'s
# iter  162   |   diff: 3.00000   |   V(start): {'s
# iter  163   |   diff: 3.00000   |   V(start): {'s
# iter  164   |   diff: 3.00000   |   V(start): {'s
# iter  165   |   diff: 3.00000   |   V(start): {'s
# iter  166   |   diff: 3.00000   |   V(start): {'s
# iter  167   |   diff: 3.00000   |   V(start): {'s
# iter  168   |   diff: 3.00000   |   V(start): {'s
# iter  169   |   diff: 3.00000   |   V(start): {'s
# iter  170   |   diff: 3.00000   |   V(start): {'s
# iter  171   |   diff: 3.00000   |   V(start): {'s
# iter  172   |   diff: 3.00000   |   V(start): {'s
# iter  173   |   diff: 3.00000   |   V(start): {'s
# iter  174   |   diff: 3.00000   |   V(start): {'s
# iter  175   |   diff: 3.00000   |   V(start): {'s
# iter  176   |   diff: 3.00000   |   V(start): {'s
# iter  177   |   diff: 3.00000   |   V(start): {'s
# iter  178   |   diff: 3.00000   |   V(start): {'s
# iter  179   |   diff: 3.00000   |   V(start): {'s
# iter  180   |   diff: 3.00000   |   V(start): {'s
# iter  181   |   diff: 3.00000   |   V(start): {'s
# iter  182   |   diff: 3.00000   |   V(start): {'s
# iter  183   |   diff: 3.00000   |   V(start): {'s
# iter  184   |   diff: 3.00000   |   V(start): {'s
# iter  185   |   diff: 3.00000   |   V(start): {'s
# iter  186   |   diff: 3.00000   |   V(start): {'s
# iter  187   |   diff: 3.00000   |   V(start): {'s
# iter  188   |   diff: 3.00000   |   V(start): {'s
# iter  189   |   diff: 3.00000   |   V(start): {'s
# iter  190   |   diff: 3.00000   |   V(start): {'s
# iter  191   |   diff: 3.00000   |   V(start): {'s
# iter  192   |   diff: 3.00000   |   V(start): {'s
# iter  193   |   diff: 3.00000   |   V(start): {'s
# iter  194   |   diff: 3.00000   |   V(start): {'s
# iter  195   |   diff: 3.00000   |   V(start): {'s
# iter  196   |   diff: 3.00000   |   V(start): {'s
# iter  197   |   diff: 3.00000   |   V(start): {'s
# iter  198   |   diff: 3.00000   |   V(start): {'s
# iter  199   |   diff: 3.00000   |   V(start): {'s
# iter  200   |   diff: 3.00000   |   V(start): {'s
# iter  201   |   diff: 3.00000   |   V(start): {'s
# iter  202   |   diff: 3.00000   |   V(start): {'s
# iter  203   |   diff: 3.00000   |   V(start): {'s
# iter  204   |   diff: 3.00000   |   V(start): {'s
# iter  205   |   diff: 3.00000   |   V(start): {'s
# iter  206   |   diff: 3.00000   |   V(start): {'s
# iter  207   |   diff: 3.00000   |   V(start): {'s
# iter  208   |   diff: 3.00000   |   V(start): {'s
# iter  209   |   diff: 3.00000   |   V(start): {'s
# iter  210   |   diff: 3.00000   |   V(start): {'s
# iter  211   |   diff: 3.00000   |   V(start): {'s
# iter  212   |   diff: 3.00000   |   V(start): {'s
# iter  213   |   diff: 3.00000   |   V(start): {'s
# iter  214   |   diff: 3.00000   |   V(start): {'s
# iter  215   |   diff: 3.00000   |   V(start): {'s
# iter  216   |   diff: 3.00000   |   V(start): {'s
# iter  217   |   diff: 3.00000   |   V(start): {'s
# iter  218   |   diff: 3.00000   |   V(start): {'s
# iter  219   |   diff: 3.00000   |   V(start): {'s
# iter  220   |   diff: 3.00000   |   V(start): {'s
# iter  221   |   diff: 3.00000   |   V(start): {'s
# iter  222   |   diff: 3.00000   |   V(start): {'s
# iter  223   |   diff: 3.00000   |   V(start): {'s
# iter  224   |   diff: 3.00000   |   V(start): {'s
# iter  225   |   diff: 3.00000   |   V(start): {'s
# iter  226   |   diff: 3.00000   |   V(start): {'s
# iter  227   |   diff: 3.00000   |   V(start): {'s
# iter  228   |   diff: 3.00000   |   V(start): {'s
# iter  229   |   diff: 3.00000   |   V(start): {'s
# iter  230   |   diff: 3.00000   |   V(start): {'s
# iter  231   |   diff: 3.00000   |   V(start): {'s
# iter  232   |   diff: 3.00000   |   V(start): {'s
# iter  233   |   diff: 3.00000   |   V(start): {'s
# iter  234   |   diff: 3.00000   |   V(start): {'s
# iter  235   |   diff: 3.00000   |   V(start): {'s
# iter  236   |   diff: 3.00000   |   V(start): {'s
# iter  237   |   diff: 3.00000   |   V(start): {'s
# iter  238   |   diff: 3.00000   |   V(start): {'s
# iter  239   |   diff: 3.00000   |   V(start): {'s
# iter  240   |   diff: 3.00000   |   V(start): {'s
# iter  241   |   diff: 3.00000   |   V(start): {'s
# iter  242   |   diff: 3.00000   |   V(start): {'s
# iter  243   |   diff: 3.00000   |   V(start): {'s
# iter  244   |   diff: 3.00000   |   V(start): {'s
# iter  245   |   diff: 3.00000   |   V(start): {'s
# iter  246   |   diff: 3.00000   |   V(start): {'s
# iter  247   |   diff: 3.00000   |   V(start): {'s
# iter  248   |   diff: 3.00000   |   V(start): {'s
# iter  249   |   diff: 3.00000   |   V(start): {'s
# iter  250   |   diff: 3.00000   |   V(start): {'s
# iter  251   |   diff: 3.00000   |   V(start): {'s
# iter  252   |   diff: 3.00000   |   V(start): {'s
# iter  253   |   diff: 3.00000   |   V(start): {'s
# iter  254   |   diff: 3.00000   |   V(start): {'s
# iter  255   |   diff: 3.00000   |   V(start): {'s
# iter  256   |   diff: 3.00000   |   V(start): {'s
# iter  257   |   diff: 3.00000   |   V(start): {'s
# iter  258   |   diff: 3.00000   |   V(start): {'s
# iter  259   |   diff: 3.00000   |   V(start): {'s
# iter  260   |   diff: 3.00000   |   V(start): {'s
# iter  261   |   diff: 3.00000   |   V(start): {'s
# iter  262   |   diff: 3.00000   |   V(start): {'s
# iter  263   |   diff: 3.00000   |   V(start): {'s
# iter  264   |   diff: 3.00000   |   V(start): {'s
# iter  265   |   diff: 3.00000   |   V(start): {'s
# iter  266   |   diff: 3.00000   |   V(start): {'s
# iter  267   |   diff: 3.00000   |   V(start): {'s
# iter  268   |   diff: 3.00000   |   V(start): {'s
# iter  269   |   diff: 3.00000   |   V(start): {'s
# iter  270   |   diff: 3.00000   |   V(start): {'s
# iter  271   |   diff: 3.00000   |   V(start): {'s
# iter  272   |   diff: 3.00000   |   V(start): {'s
# iter  273   |   diff: 3.00000   |   V(start): {'s
# iter  274   |   diff: 3.00000   |   V(start): {'s
# iter  275   |   diff: 3.00000   |   V(start): {'s
# iter  276   |   diff: 3.00000   |   V(start): {'s
# iter  277   |   diff: 3.00000   |   V(start): {'s
# iter  278   |   diff: 3.00000   |   V(start): {'s
# iter  279   |   diff: 3.00000   |   V(start): {'s
# iter  280   |   diff: 3.00000   |   V(start): {'s
# iter  281   |   diff: 3.00000   |   V(start): {'s
# iter  282   |   diff: 3.00000   |   V(start): {'s
# iter  283   |   diff: 3.00000   |   V(start): {'s
# iter  284   |   diff: 3.00000   |   V(start): {'s
# iter  285   |   diff: 3.00000   |   V(start): {'s
# iter  286   |   diff: 3.00000   |   V(start): {'s
# iter  287   |   diff: 3.00000   |   V(start): {'s
# iter  288   |   diff: 3.00000   |   V(start): {'s
# iter  289   |   diff: 3.00000   |   V(start): {'s
# iter  290   |   diff: 3.00000   |   V(start): {'s
# iter  291   |   diff: 3.00000   |   V(start): {'s
# iter  292   |   diff: 3.00000   |   V(start): {'s
# iter  293   |   diff: 3.00000   |   V(start): {'s
# iter  294   |   diff: 3.00000   |   V(start): {'s
# iter  295   |   diff: 3.00000   |   V(start): {'s
# iter  296   |   diff: 3.00000   |   V(start): {'s
# iter  297   |   diff: 3.00000   |   V(start): {'s
# iter  298   |   diff: 3.00000   |   V(start): {'s
# iter  299   |   diff: 3.00000   |   V(start): {'s
# iter  300   |   diff: 3.00000   |   V(start): {'s
# iter  301   |   diff: 3.00000   |   V(start): {'s
# iter  302   |   diff: 3.00000   |   V(start): {'s
# iter  303   |   diff: 3.00000   |   V(start): {'s
# iter  304   |   diff: 3.00000   |   V(start): {'s
# iter  305   |   diff: 3.00000   |   V(start): {'s
# iter  306   |   diff: 3.00000   |   V(start): {'s
# iter  307   |   diff: 3.00000   |   V(start): {'s
# iter  308   |   diff: 3.00000   |   V(start): {'s
# iter  309   |   diff: 3.00000   |   V(start): {'s
# iter  310   |   diff: 3.00000   |   V(start): {'s
# iter  311   |   diff: 3.00000   |   V(start): {'s
# iter  312   |   diff: 3.00000   |   V(start): {'s
# iter  313   |   diff: 3.00000   |   V(start): {'s
# iter  314   |   diff: 3.00000   |   V(start): {'s
# iter  315   |   diff: 3.00000   |   V(start): {'s
# iter  316   |   diff: 3.00000   |   V(start): {'s
# iter  317   |   diff: 3.00000   |   V(start): {'s
# iter  318   |   diff: 3.00000   |   V(start): {'s
# iter  319   |   diff: 3.00000   |   V(start): {'s
# iter  320   |   diff: 3.00000   |   V(start): {'s
# iter  321   |   diff: 3.00000   |   V(start): {'s
# iter  322   |   diff: 3.00000   |   V(start): {'s
# iter  323   |   diff: 3.00000   |   V(start): {'s
# iter  324   |   diff: 3.00000   |   V(start): {'s
# iter  325   |   diff: 3.00000   |   V(start): {'s
# iter  326   |   diff: 3.00000   |   V(start): {'s
# iter  327   |   diff: 3.00000   |   V(start): {'s
# iter  328   |   diff: 3.00000   |   V(start): {'s
# iter  329   |   diff: 3.00000   |   V(start): {'s
# iter  330   |   diff: 3.00000   |   V(start): {'s
# iter  331   |   diff: 3.00000   |   V(start): {'s
# iter  332   |   diff: 3.00000   |   V(start): {'s
# iter  333   |   diff: 3.00000   |   V(start): {'s
# iter  334   |   diff: 3.00000   |   V(start): {'s
# iter  335   |   diff: 3.00000   |   V(start): {'s
# iter  336   |   diff: 3.00000   |   V(start): {'s
# iter  337   |   diff: 3.00000   |   V(start): {'s
# iter  338   |   diff: 3.00000   |   V(start): {'s
# iter  339   |   diff: 3.00000   |   V(start): {'s
# iter  340   |   diff: 3.00000   |   V(start): {'s
# iter  341   |   diff: 3.00000   |   V(start): {'s
# iter  342   |   diff: 3.00000   |   V(start): {'s
# iter  343   |   diff: 3.00000   |   V(start): {'s
# iter  344   |   diff: 3.00000   |   V(start): {'s
# iter  345   |   diff: 3.00000   |   V(start): {'s
# iter  346   |   diff: 3.00000   |   V(start): {'s
# iter  347   |   diff: 3.00000   |   V(start): {'s
# iter  348   |   diff: 3.00000   |   V(start): {'s
# iter  349   |   diff: 3.00000   |   V(start): {'s
# iter  350   |   diff: 3.00000   |   V(start): {'s
# iter  351   |   diff: 3.00000   |   V(start): {'s
# iter  352   |   diff: 3.00000   |   V(start): {'s
# iter  353   |   diff: 3.00000   |   V(start): {'s
# iter  354   |   diff: 3.00000   |   V(start): {'s
# iter  355   |   diff: 3.00000   |   V(start): {'s
# iter  356   |   diff: 3.00000   |   V(start): {'s
# iter  357   |   diff: 3.00000   |   V(start): {'s
# iter  358   |   diff: 3.00000   |   V(start): {'s
# iter  359   |   diff: 3.00000   |   V(start): {'s
# iter  360   |   diff: 3.00000   |   V(start): {'s
# iter  361   |   diff: 3.00000   |   V(start): {'s
# iter  362   |   diff: 3.00000   |   V(start): {'s
# iter  363   |   diff: 3.00000   |   V(start): {'s
# iter  364   |   diff: 3.00000   |   V(start): {'s
# iter  365   |   diff: 3.00000   |   V(start): {'s
# iter  366   |   diff: 3.00000   |   V(start): {'s
# iter  367   |   diff: 3.00000   |   V(start): {'s
# iter  368   |   diff: 3.00000   |   V(start): {'s
# iter  369   |   diff: 3.00000   |   V(start): {'s
# iter  370   |   diff: 3.00000   |   V(start): {'s
# iter  371   |   diff: 3.00000   |   V(start): {'s
# iter  372   |   diff: 3.00000   |   V(start): {'s
# iter  373   |   diff: 3.00000   |   V(start): {'s
# iter  374   |   diff: 3.00000   |   V(start): {'s
# iter  375   |   diff: 3.00000   |   V(start): {'s
# iter  376   |   diff: 3.00000   |   V(start): {'s
# iter  377   |   diff: 3.00000   |   V(start): {'s
# iter  378   |   diff: 3.00000   |   V(start): {'s
# iter  379   |   diff: 3.00000   |   V(start): {'s
# iter  380   |   diff: 3.00000   |   V(start): {'s
# iter  381   |   diff: 3.00000   |   V(start): {'s
# iter  382   |   diff: 3.00000   |   V(start): {'s
# iter  383   |   diff: 3.00000   |   V(start): {'s
# iter  384   |   diff: 3.00000   |   V(start): {'s
# iter  385   |   diff: 3.00000   |   V(start): {'s
# iter  386   |   diff: 3.00000   |   V(start): {'s
# iter  387   |   diff: 3.00000   |   V(start): {'s
# iter  388   |   diff: 3.00000   |   V(start): {'s
# iter  389   |   diff: 3.00000   |   V(start): {'s
# iter  390   |   diff: 3.00000   |   V(start): {'s
# iter  391   |   diff: 3.00000   |   V(start): {'s
# iter  392   |   diff: 3.00000   |   V(start): {'s
# iter  393   |   diff: 3.00000   |   V(start): {'s
# iter  394   |   diff: 3.00000   |   V(start): {'s
# iter  395   |   diff: 3.00000   |   V(start): {'s
# iter  396   |   diff: 3.00000   |   V(start): {'s
# iter  397   |   diff: 3.00000   |   V(start): {'s
# iter  398   |   diff: 3.00000   |   V(start): {'s
# iter  399   |   diff: 3.00000   |   V(start): {'s
# iter  400   |   diff: 3.00000   |   V(start): {'s
# iter  401   |   diff: 3.00000   |   V(start): {'s
# iter  402   |   diff: 3.00000   |   V(start): {'s
# iter  403   |   diff: 3.00000   |   V(start): {'s
# iter  404   |   diff: 3.00000   |   V(start): {'s
# iter  405   |   diff: 3.00000   |   V(start): {'s
# iter  406   |   diff: 3.00000   |   V(start): {'s
# iter  407   |   diff: 3.00000   |   V(start): {'s
# iter  408   |   diff: 3.00000   |   V(start): {'s
# iter  409   |   diff: 3.00000   |   V(start): {'s
# iter  410   |   diff: 3.00000   |   V(start): {'s
# iter  411   |   diff: 3.00000   |   V(start): {'s
# iter  412   |   diff: 3.00000   |   V(start): {'s
# iter  413   |   diff: 3.00000   |   V(start): {'s
# iter  414   |   diff: 3.00000   |   V(start): {'s
# iter  415   |   diff: 3.00000   |   V(start): {'s
# iter  416   |   diff: 3.00000   |   V(start): {'s
# iter  417   |   diff: 3.00000   |   V(start): {'s
# iter  418   |   diff: 3.00000   |   V(start): {'s
# iter  419   |   diff: 3.00000   |   V(start): {'s
# iter  420   |   diff: 3.00000   |   V(start): {'s
# iter  421   |   diff: 3.00000   |   V(start): {'s
# iter  422   |   diff: 3.00000   |   V(start): {'s
# iter  423   |   diff: 3.00000   |   V(start): {'s
# iter  424   |   diff: 3.00000   |   V(start): {'s
# iter  425   |   diff: 3.00000   |   V(start): {'s
# iter  426   |   diff: 3.00000   |   V(start): {'s
# iter  427   |   diff: 3.00000   |   V(start): {'s
# iter  428   |   diff: 3.00000   |   V(start): {'s
# iter  429   |   diff: 3.00000   |   V(start): {'s
# iter  430   |   diff: 3.00000   |   V(start): {'s
# iter  431   |   diff: 3.00000   |   V(start): {'s
# iter  432   |   diff: 3.00000   |   V(start): {'s
# iter  433   |   diff: 3.00000   |   V(start): {'s
# iter  434   |   diff: 3.00000   |   V(start): {'s
# iter  435   |   diff: 3.00000   |   V(start): {'s
# iter  436   |   diff: 3.00000   |   V(start): {'s
# iter  437   |   diff: 3.00000   |   V(start): {'s
# iter  438   |   diff: 3.00000   |   V(start): {'s
# iter  439   |   diff: 3.00000   |   V(start): {'s
# iter  440   |   diff: 3.00000   |   V(start): {'s
# iter  441   |   diff: 3.00000   |   V(start): {'s
# iter  442   |   diff: 3.00000   |   V(start): {'s
# iter  443   |   diff: 3.00000   |   V(start): {'s
# iter  444   |   diff: 3.00000   |   V(start): {'s
# iter  445   |   diff: 3.00000   |   V(start): {'s
# iter  446   |   diff: 3.00000   |   V(start): {'s
# iter  447   |   diff: 3.00000   |   V(start): {'s
# iter  448   |   diff: 3.00000   |   V(start): {'s
# iter  449   |   diff: 3.00000   |   V(start): {'s
# iter  450   |   diff: 3.00000   |   V(start): {'s
# iter  451   |   diff: 3.00000   |   V(start): {'s
# iter  452   |   diff: 3.00000   |   V(start): {'s
# iter  453   |   diff: 3.00000   |   V(start): {'s
# iter  454   |   diff: 3.00000   |   V(start): {'s
# iter  455   |   diff: 3.00000   |   V(start): {'s
# iter  456   |   diff: 3.00000   |   V(start): {'s
# iter  457   |   diff: 3.00000   |   V(start): {'s
# iter  458   |   diff: 3.00000   |   V(start): {'s
# iter  459   |   diff: 3.00000   |   V(start): {'s
# iter  460   |   diff: 3.00000   |   V(start): {'s
# iter  461   |   diff: 3.00000   |   V(start): {'s
# iter  462   |   diff: 3.00000   |   V(start): {'s
# iter  463   |   diff: 3.00000   |   V(start): {'s
# iter  464   |   diff: 3.00000   |   V(start): {'s
# iter  465   |   diff: 3.00000   |   V(start): {'s
# iter  466   |   diff: 3.00000   |   V(start): {'s
# iter  467   |   diff: 3.00000   |   V(start): {'s
# iter  468   |   diff: 3.00000   |   V(start): {'s
# iter  469   |   diff: 3.00000   |   V(start): {'s
# iter  470   |   diff: 3.00000   |   V(start): {'s
# iter  471   |   diff: 3.00000   |   V(start): {'s
# iter  472   |   diff: 3.00000   |   V(start): {'s
# iter  473   |   diff: 3.00000   |   V(start): {'s
# iter  474   |   diff: 3.00000   |   V(start): {'s
# iter  475   |   diff: 3.00000   |   V(start): {'s
# iter  476   |   diff: 3.00000   |   V(start): {'s
# iter  477   |   diff: 3.00000   |   V(start): {'s
# iter  478   |   diff: 3.00000   |   V(start): {'s
# iter  479   |   diff: 3.00000   |   V(start): {'s
# iter  480   |   diff: 3.00000   |   V(start): {'s
# iter  481   |   diff: 3.00000   |   V(start): {'s
# iter  482   |   diff: 3.00000   |   V(start): {'s
# iter  483   |   diff: 3.00000   |   V(start): {'s
# iter  484   |   diff: 3.00000   |   V(start): {'s
# iter  485   |   diff: 3.00000   |   V(start): {'s
# iter  486   |   diff: 3.00000   |   V(start): {'s
# iter  487   |   diff: 3.00000   |   V(start): {'s
# iter  488   |   diff: 3.00000   |   V(start): {'s
# iter  489   |   diff: 3.00000   |   V(start): {'s
# iter  490   |   diff: 3.00000   |   V(start): {'s
# iter  491   |   diff: 3.00000   |   V(start): {'s
# iter  492   |   diff: 3.00000   |   V(start): {'s
# iter  493   |   diff: 3.00000   |   V(start): {'s
# iter  494   |   diff: 3.00000   |   V(start): {'s
# iter  495   |   diff: 3.00000   |   V(start): {'s
# iter  496   |   diff: 3.00000   |   V(start): {'s
# iter  497   |   diff: 3.00000   |   V(start): {'s
# iter  498   |   diff: 3.00000   |   V(start): {'s
# iter  499   |   diff: 3.00000   |   V(start): {'s
# iter  500   |   diff: 3.00000   |   V(start): {'s
# iter  501   |   diff: 3.00000   |   V(start): {'s
# iter  502   |   diff: 3.00000   |   V(start): {'s
# iter  503   |   diff: 3.00000   |   V(start): {'s
# iter  504   |   diff: 3.00000   |   V(start): {'s
# iter  505   |   diff: 3.00000   |   V(start): {'s
# iter  506   |   diff: 3.00000   |   V(start): {'s
# iter  507   |   diff: 3.00000   |   V(start): {'s
# iter  508   |   diff: 3.00000   |   V(start): {'s
# iter  509   |   diff: 3.00000   |   V(start): {'s
# iter  510   |   diff: 3.00000   |   V(start): {'s
# iter  511   |   diff: 3.00000   |   V(start): {'s
# iter  512   |   diff: 3.00000   |   V(start): {'s
# iter  513   |   diff: 3.00000   |   V(start): {'s
# iter  514   |   diff: 3.00000   |   V(start): {'s
# iter  515   |   diff: 3.00000   |   V(start): {'s
# iter  516   |   diff: 3.00000   |   V(start): {'s
# iter  517   |   diff: 3.00000   |   V(start): {'s
# iter  518   |   diff: 3.00000   |   V(start): {'s
# iter  519   |   diff: 3.00000   |   V(start): {'s
# iter  520   |   diff: 3.00000   |   V(start): {'s
# iter  521   |   diff: 3.00000   |   V(start): {'s
# iter  522   |   diff: 3.00000   |   V(start): {'s
# iter  523   |   diff: 3.00000   |   V(start): {'s
# iter  524   |   diff: 3.00000   |   V(start): {'s
# iter  525   |   diff: 3.00000   |   V(start): {'s
# iter  526   |   diff: 3.00000   |   V(start): {'s
# iter  527   |   diff: 3.00000   |   V(start): {'s
# iter  528   |   diff: 3.00000   |   V(start): {'s
# iter  529   |   diff: 3.00000   |   V(start): {'s
# iter  530   |   diff: 3.00000   |   V(start): {'s
# iter  531   |   diff: 3.00000   |   V(start): {'s
# iter  532   |   diff: 3.00000   |   V(start): {'s
# iter  533   |   diff: 3.00000   |   V(start): {'s
# iter  534   |   diff: 3.00000   |   V(start): {'s
# iter  535   |   diff: 3.00000   |   V(start): {'s
# iter  536   |   diff: 3.00000   |   V(start): {'s
# iter  537   |   diff: 3.00000   |   V(start): {'s
# iter  538   |   diff: 3.00000   |   V(start): {'s
# iter  539   |   diff: 3.00000   |   V(start): {'s
# iter  540   |   diff: 3.00000   |   V(start): {'s
# iter  541   |   diff: 3.00000   |   V(start): {'s
# iter  542   |   diff: 3.00000   |   V(start): {'s
# iter  543   |   diff: 3.00000   |   V(start): {'s
# iter  544   |   diff: 3.00000   |   V(start): {'s
# iter  545   |   diff: 3.00000   |   V(start): {'s
# iter  546   |   diff: 3.00000   |   V(start): {'s
# iter  547   |   diff: 3.00000   |   V(start): {'s
# iter  548   |   diff: 3.00000   |   V(start): {'s
# iter  549   |   diff: 3.00000   |   V(start): {'s
# iter  550   |   diff: 3.00000   |   V(start): {'s
# iter  551   |   diff: 3.00000   |   V(start): {'s
# iter  552   |   diff: 3.00000   |   V(start): {'s
# iter  553   |   diff: 3.00000   |   V(start): {'s
# iter  554   |   diff: 3.00000   |   V(start): {'s
# iter  555   |   diff: 3.00000   |   V(start): {'s
# iter  556   |   diff: 3.00000   |   V(start): {'s
# iter  557   |   diff: 3.00000   |   V(start): {'s
# iter  558   |   diff: 3.00000   |   V(start): {'s
# iter  559   |   diff: 3.00000   |   V(start): {'s
# iter  560   |   diff: 3.00000   |   V(start): {'s
# iter  561   |   diff: 3.00000   |   V(start): {'s
# iter  562   |   diff: 3.00000   |   V(start): {'s
# iter  563   |   diff: 3.00000   |   V(start): {'s
# iter  564   |   diff: 3.00000   |   V(start): {'s
# iter  565   |   diff: 3.00000   |   V(start): {'s
# iter  566   |   diff: 3.00000   |   V(start): {'s
# iter  567   |   diff: 3.00000   |   V(start): {'s
# iter  568   |   diff: 3.00000   |   V(start): {'s
# iter  569   |   diff: 3.00000   |   V(start): {'s
# iter  570   |   diff: 3.00000   |   V(start): {'s
# iter  571   |   diff: 3.00000   |   V(start): {'s
# iter  572   |   diff: 3.00000   |   V(start): {'s
# iter  573   |   diff: 3.00000   |   V(start): {'s
# iter  574   |   diff: 3.00000   |   V(start): {'s
# iter  575   |   diff: 3.00000   |   V(start): {'s
# iter  576   |   diff: 3.00000   |   V(start): {'s
# iter  577   |   diff: 3.00000   |   V(start): {'s
# iter  578   |   diff: 3.00000   |   V(start): {'s
# iter  579   |   diff: 3.00000   |   V(start): {'s
# iter  580   |   diff: 3.00000   |   V(start): {'s
# iter  581   |   diff: 3.00000   |   V(start): {'s
# iter  582   |   diff: 3.00000   |   V(start): {'s
# iter  583   |   diff: 3.00000   |   V(start): {'s
# iter  584   |   diff: 3.00000   |   V(start): {'s
# iter  585   |   diff: 3.00000   |   V(start): {'s
# iter  586   |   diff: 3.00000   |   V(start): {'s
# iter  587   |   diff: 3.00000   |   V(start): {'s
# iter  588   |   diff: 3.00000   |   V(start): {'s
# iter  589   |   diff: 3.00000   |   V(start): {'s
# iter  590   |   diff: 3.00000   |   V(start): {'s
# iter  591   |   diff: 3.00000   |   V(start): {'s
# iter  592   |   diff: 3.00000   |   V(start): {'s
# iter  593   |   diff: 3.00000   |   V(start): {'s
# iter  594   |   diff: 3.00000   |   V(start): {'s
# iter  595   |   diff: 3.00000   |   V(start): {'s
# iter  596   |   diff: 3.00000   |   V(start): {'s
# iter  597   |   diff: 3.00000   |   V(start): {'s
# iter  598   |   diff: 3.00000   |   V(start): {'s
# iter  599   |   diff: 3.00000   |   V(start): {'s
# iter  600   |   diff: 3.00000   |   V(start): {'s
# iter  601   |   diff: 3.00000   |   V(start): {'s
# iter  602   |   diff: 3.00000   |   V(start): {'s
# iter  603   |   diff: 3.00000   |   V(start): {'s
# iter  604   |   diff: 3.00000   |   V(start): {'s
# iter  605   |   diff: 3.00000   |   V(start): {'s
# iter  606   |   diff: 3.00000   |   V(start): {'s
# iter  607   |   diff: 3.00000   |   V(start): {'s
# iter  608   |   diff: 3.00000   |   V(start): {'s
# iter  609   |   diff: 3.00000   |   V(start): {'s
# iter  610   |   diff: 3.00000   |   V(start): {'s
# iter  611   |   diff: 3.00000   |   V(start): {'s
# iter  612   |   diff: 3.00000   |   V(start): {'s
# iter  613   |   diff: 3.00000   |   V(start): {'s
# iter  614   |   diff: 3.00000   |   V(start): {'s
# iter  615   |   diff: 3.00000   |   V(start): {'s
# iter  616   |   diff: 3.00000   |   V(start): {'s
# iter  617   |   diff: 3.00000   |   V(start): {'s
# iter  618   |   diff: 3.00000   |   V(start): {'s
# iter  619   |   diff: 3.00000   |   V(start): {'s
# iter  620   |   diff: 3.00000   |   V(start): {'s
# iter  621   |   diff: 3.00000   |   V(start): {'s
# iter  622   |   diff: 3.00000   |   V(start): {'s
# iter  623   |   diff: 3.00000   |   V(start): {'s
# iter  624   |   diff: 3.00000   |   V(start): {'s
# iter  625   |   diff: 3.00000   |   V(start): {'s
# iter  626   |   diff: 3.00000   |   V(start): {'s
# iter  627   |   diff: 3.00000   |   V(start): {'s
# iter  628   |   diff: 3.00000   |   V(start): {'s
# iter  629   |   diff: 3.00000   |   V(start): {'s
# iter  630   |   diff: 3.00000   |   V(start): {'s
# iter  631   |   diff: 3.00000   |   V(start): {'s
# iter  632   |   diff: 3.00000   |   V(start): {'s
# iter  633   |   diff: 3.00000   |   V(start): {'s
# iter  634   |   diff: 3.00000   |   V(start): {'s
# iter  635   |   diff: 3.00000   |   V(start): {'s
# iter  636   |   diff: 3.00000   |   V(start): {'s
# iter  637   |   diff: 3.00000   |   V(start): {'s
# iter  638   |   diff: 3.00000   |   V(start): {'s
# iter  639   |   diff: 3.00000   |   V(start): {'s
# iter  640   |   diff: 3.00000   |   V(start): {'s
# iter  641   |   diff: 3.00000   |   V(start): {'s
# iter  642   |   diff: 3.00000   |   V(start): {'s
# iter  643   |   diff: 3.00000   |   V(start): {'s
# iter  644   |   diff: 3.00000   |   V(start): {'s
# iter  645   |   diff: 3.00000   |   V(start): {'s
# iter  646   |   diff: 3.00000   |   V(start): {'s
# iter  647   |   diff: 3.00000   |   V(start): {'s
# iter  648   |   diff: 3.00000   |   V(start): {'s
# iter  649   |   diff: 3.00000   |   V(start): {'s
# iter  650   |   diff: 3.00000   |   V(start): {'s
# iter  651   |   diff: 3.00000   |   V(start): {'s
# iter  652   |   diff: 3.00000   |   V(start): {'s
# iter  653   |   diff: 3.00000   |   V(start): {'s
# iter  654   |   diff: 3.00000   |   V(start): {'s
# iter  655   |   diff: 3.00000   |   V(start): {'s
# iter  656   |   diff: 3.00000   |   V(start): {'s
# iter  657   |   diff: 3.00000   |   V(start): {'s
# iter  658   |   diff: 3.00000   |   V(start): {'s
# iter  659   |   diff: 3.00000   |   V(start): {'s
# iter  660   |   diff: 3.00000   |   V(start): {'s
# iter  661   |   diff: 3.00000   |   V(start): {'s
# iter  662   |   diff: 3.00000   |   V(start): {'s
# iter  663   |   diff: 3.00000   |   V(start): {'s
# iter  664   |   diff: 3.00000   |   V(start): {'s
# iter  665   |   diff: 3.00000   |   V(start): {'s
# iter  666   |   diff: 3.00000   |   V(start): {'s
# iter  667   |   diff: 3.00000   |   V(start): {'s
# iter  668   |   diff: 3.00000   |   V(start): {'s
# iter  669   |   diff: 3.00000   |   V(start): {'s
# iter  670   |   diff: 3.00000   |   V(start): {'s
# iter  671   |   diff: 3.00000   |   V(start): {'s
# iter  672   |   diff: 3.00000   |   V(start): {'s
# iter  673   |   diff: 3.00000   |   V(start): {'s
# iter  674   |   diff: 3.00000   |   V(start): {'s
# iter  675   |   diff: 3.00000   |   V(start): {'s
# iter  676   |   diff: 3.00000   |   V(start): {'s
# iter  677   |   diff: 3.00000   |   V(start): {'s
# iter  678   |   diff: 3.00000   |   V(start): {'s
# iter  679   |   diff: 3.00000   |   V(start): {'s
# iter  680   |   diff: 3.00000   |   V(start): {'s
# iter  681   |   diff: 3.00000   |   V(start): {'s
# iter  682   |   diff: 3.00000   |   V(start): {'s
# iter  683   |   diff: 3.00000   |   V(start): {'s
# iter  684   |   diff: 3.00000   |   V(start): {'s
# iter  685   |   diff: 3.00000   |   V(start): {'s
# iter  686   |   diff: 3.00000   |   V(start): {'s
# iter  687   |   diff: 3.00000   |   V(start): {'s
# iter  688   |   diff: 3.00000   |   V(start): {'s
# iter  689   |   diff: 3.00000   |   V(start): {'s
# iter  690   |   diff: 3.00000   |   V(start): {'s
# iter  691   |   diff: 3.00000   |   V(start): {'s
# iter  692   |   diff: 3.00000   |   V(start): {'s
# iter  693   |   diff: 3.00000   |   V(start): {'s
# iter  694   |   diff: 3.00000   |   V(start): {'s
# iter  695   |   diff: 3.00000   |   V(start): {'s
# iter  696   |   diff: 3.00000   |   V(start): {'s
# iter  697   |   diff: 3.00000   |   V(start): {'s
# iter  698   |   diff: 3.00000   |   V(start): {'s
# iter  699   |   diff: 3.00000   |   V(start): {'s
# iter  700   |   diff: 3.00000   |   V(start): {'s
# iter  701   |   diff: 3.00000   |   V(start): {'s
# iter  702   |   diff: 3.00000   |   V(start): {'s
# iter  703   |   diff: 3.00000   |   V(start): {'s
# iter  704   |   diff: 3.00000   |   V(start): {'s
# iter  705   |   diff: 3.00000   |   V(start): {'s
# iter  706   |   diff: 3.00000   |   V(start): {'s
# iter  707   |   diff: 3.00000   |   V(start): {'s
# iter  708   |   diff: 3.00000   |   V(start): {'s
# iter  709   |   diff: 3.00000   |   V(start): {'s
# iter  710   |   diff: 3.00000   |   V(start): {'s
# iter  711   |   diff: 3.00000   |   V(start): {'s
# iter  712   |   diff: 3.00000   |   V(start): {'s
# iter  713   |   diff: 3.00000   |   V(start): {'s
# iter  714   |   diff: 3.00000   |   V(start): {'s
# iter  715   |   diff: 3.00000   |   V(start): {'s
# iter  716   |   diff: 3.00000   |   V(start): {'s
# iter  717   |   diff: 3.00000   |   V(start): {'s
# iter  718   |   diff: 3.00000   |   V(start): {'s
# iter  719   |   diff: 3.00000   |   V(start): {'s
# iter  720   |   diff: 3.00000   |   V(start): {'s
# iter  721   |   diff: 3.00000   |   V(start): {'s
# iter  722   |   diff: 3.00000   |   V(start): {'s
# iter  723   |   diff: 3.00000   |   V(start): {'s
# iter  724   |   diff: 3.00000   |   V(start): {'s
# iter  725   |   diff: 3.00000   |   V(start): {'s
# iter  726   |   diff: 3.00000   |   V(start): {'s
# iter  727   |   diff: 3.00000   |   V(start): {'s
# iter  728   |   diff: 3.00000   |   V(start): {'s
# iter  729   |   diff: 3.00000   |   V(start): {'s
# iter  730   |   diff: 3.00000   |   V(start): {'s
# iter  731   |   diff: 3.00000   |   V(start): {'s
# iter  732   |   diff: 3.00000   |   V(start): {'s
# iter  733   |   diff: 3.00000   |   V(start): {'s
# iter  734   |   diff: 3.00000   |   V(start): {'s
# iter  735   |   diff: 3.00000   |   V(start): {'s
# iter  736   |   diff: 3.00000   |   V(start): {'s
# iter  737   |   diff: 3.00000   |   V(start): {'s
# iter  738   |   diff: 3.00000   |   V(start): {'s
# iter  739   |   diff: 3.00000   |   V(start): {'s
# iter  740   |   diff: 3.00000   |   V(start): {'s
# iter  741   |   diff: 3.00000   |   V(start): {'s
# iter  742   |   diff: 3.00000   |   V(start): {'s
# iter  743   |   diff: 3.00000   |   V(start): {'s
# iter  744   |   diff: 3.00000   |   V(start): {'s
# iter  745   |   diff: 3.00000   |   V(start): {'s
# iter  746   |   diff: 3.00000   |   V(start): {'s
# iter  747   |   diff: 3.00000   |   V(start): {'s
# iter  748   |   diff: 3.00000   |   V(start): {'s
# iter  749   |   diff: 3.00000   |   V(start): {'s
# iter  750   |   diff: 3.00000   |   V(start): {'s
# iter  751   |   diff: 3.00000   |   V(start): {'s
# iter  752   |   diff: 3.00000   |   V(start): {'s
# iter  753   |   diff: 3.00000   |   V(start): {'s
# iter  754   |   diff: 3.00000   |   V(start): {'s
# iter  755   |   diff: 3.00000   |   V(start): {'s
# iter  756   |   diff: 3.00000   |   V(start): {'s
# iter  757   |   diff: 3.00000   |   V(start): {'s
# iter  758   |   diff: 3.00000   |   V(start): {'s
# iter  759   |   diff: 3.00000   |   V(start): {'s
# iter  760   |   diff: 3.00000   |   V(start): {'s
# iter  761   |   diff: 3.00000   |   V(start): {'s
# iter  762   |   diff: 3.00000   |   V(start): {'s
# iter  763   |   diff: 3.00000   |   V(start): {'s
# iter  764   |   diff: 3.00000   |   V(start): {'s
# iter  765   |   diff: 3.00000   |   V(start): {'s
# iter  766   |   diff: 3.00000   |   V(start): {'s
# iter  767   |   diff: 3.00000   |   V(start): {'s
# iter  768   |   diff: 3.00000   |   V(start): {'s
# iter  769   |   diff: 3.00000   |   V(start): {'s
# iter  770   |   diff: 3.00000   |   V(start): {'s
# iter  771   |   diff: 3.00000   |   V(start): {'s
# iter  772   |   diff: 3.00000   |   V(start): {'s
# iter  773   |   diff: 3.00000   |   V(start): {'s
# iter  774   |   diff: 3.00000   |   V(start): {'s
# iter  775   |   diff: 3.00000   |   V(start): {'s
# iter  776   |   diff: 3.00000   |   V(start): {'s
# iter  777   |   diff: 3.00000   |   V(start): {'s
# iter  778   |   diff: 3.00000   |   V(start): {'s
# iter  779   |   diff: 3.00000   |   V(start): {'s
# iter  780   |   diff: 3.00000   |   V(start): {'s
# iter  781   |   diff: 3.00000   |   V(start): {'s
# iter  782   |   diff: 3.00000   |   V(start): {'s
# iter  783   |   diff: 3.00000   |   V(start): {'s
# iter  784   |   diff: 3.00000   |   V(start): {'s
# iter  785   |   diff: 3.00000   |   V(start): {'s
# iter  786   |   diff: 3.00000   |   V(start): {'s
# iter  787   |   diff: 3.00000   |   V(start): {'s
# iter  788   |   diff: 3.00000   |   V(start): {'s
# iter  789   |   diff: 3.00000   |   V(start): {'s
# iter  790   |   diff: 3.00000   |   V(start): {'s
# iter  791   |   diff: 3.00000   |   V(start): {'s
# iter  792   |   diff: 3.00000   |   V(start): {'s
# iter  793   |   diff: 3.00000   |   V(start): {'s
# iter  794   |   diff: 3.00000   |   V(start): {'s
# iter  795   |   diff: 3.00000   |   V(start): {'s
# iter  796   |   diff: 3.00000   |   V(start): {'s
# iter  797   |   diff: 3.00000   |   V(start): {'s
# iter  798   |   diff: 3.00000   |   V(start): {'s
# iter  799   |   diff: 3.00000   |   V(start): {'s
# iter  800   |   diff: 3.00000   |   V(start): {'s
# iter  801   |   diff: 3.00000   |   V(start): {'s
# iter  802   |   diff: 3.00000   |   V(start): {'s
# iter  803   |   diff: 3.00000   |   V(start): {'s
# iter  804   |   diff: 3.00000   |   V(start): {'s
# iter  805   |   diff: 3.00000   |   V(start): {'s
# iter  806   |   diff: 3.00000   |   V(start): {'s
# iter  807   |   diff: 3.00000   |   V(start): {'s
# iter  808   |   diff: 3.00000   |   V(start): {'s
# iter  809   |   diff: 3.00000   |   V(start): {'s
# iter  810   |   diff: 3.00000   |   V(start): {'s
# iter  811   |   diff: 3.00000   |   V(start): {'s
# iter  812   |   diff: 3.00000   |   V(start): {'s
# iter  813   |   diff: 3.00000   |   V(start): {'s
# iter  814   |   diff: 3.00000   |   V(start): {'s
# iter  815   |   diff: 3.00000   |   V(start): {'s
# iter  816   |   diff: 3.00000   |   V(start): {'s
# iter  817   |   diff: 3.00000   |   V(start): {'s
# iter  818   |   diff: 3.00000   |   V(start): {'s
# iter  819   |   diff: 3.00000   |   V(start): {'s
# iter  820   |   diff: 3.00000   |   V(start): {'s
# iter  821   |   diff: 3.00000   |   V(start): {'s
# iter  822   |   diff: 3.00000   |   V(start): {'s
# iter  823   |   diff: 3.00000   |   V(start): {'s
# iter  824   |   diff: 3.00000   |   V(start): {'s
# iter  825   |   diff: 3.00000   |   V(start): {'s
# iter  826   |   diff: 3.00000   |   V(start): {'s
# iter  827   |   diff: 3.00000   |   V(start): {'s
# iter  828   |   diff: 3.00000   |   V(start): {'s
# iter  829   |   diff: 3.00000   |   V(start): {'s
# iter  830   |   diff: 3.00000   |   V(start): {'s
# iter  831   |   diff: 3.00000   |   V(start): {'s
# iter  832   |   diff: 3.00000   |   V(start): {'s
# iter  833   |   diff: 3.00000   |   V(start): {'s
# iter  834   |   diff: 3.00000   |   V(start): {'s
# iter  835   |   diff: 3.00000   |   V(start): {'s
# iter  836   |   diff: 3.00000   |   V(start): {'s
# iter  837   |   diff: 3.00000   |   V(start): {'s
# iter  838   |   diff: 3.00000   |   V(start): {'s
# iter  839   |   diff: 3.00000   |   V(start): {'s
# iter  840   |   diff: 3.00000   |   V(start): {'s
# iter  841   |   diff: 3.00000   |   V(start): {'s
# iter  842   |   diff: 3.00000   |   V(start): {'s
# iter  843   |   diff: 3.00000   |   V(start): {'s
# iter  844   |   diff: 3.00000   |   V(start): {'s
# iter  845   |   diff: 3.00000   |   V(start): {'s
# iter  846   |   diff: 3.00000   |   V(start): {'s
# iter  847   |   diff: 3.00000   |   V(start): {'s
# iter  848   |   diff: 3.00000   |   V(start): {'s
# iter  849   |   diff: 3.00000   |   V(start): {'s
# iter  850   |   diff: 3.00000   |   V(start): {'s
# iter  851   |   diff: 3.00000   |   V(start): {'s
# iter  852   |   diff: 3.00000   |   V(start): {'s
# iter  853   |   diff: 3.00000   |   V(start): {'s
# iter  854   |   diff: 3.00000   |   V(start): {'s
# iter  855   |   diff: 3.00000   |   V(start): {'s
# iter  856   |   diff: 3.00000   |   V(start): {'s
# iter  857   |   diff: 3.00000   |   V(start): {'s
# iter  858   |   diff: 3.00000   |   V(start): {'s
# iter  859   |   diff: 3.00000   |   V(start): {'s
# iter  860   |   diff: 3.00000   |   V(start): {'s
# iter  861   |   diff: 3.00000   |   V(start): {'s
# iter  862   |   diff: 3.00000   |   V(start): {'s
# iter  863   |   diff: 3.00000   |   V(start): {'s
# iter  864   |   diff: 3.00000   |   V(start): {'s
# iter  865   |   diff: 3.00000   |   V(start): {'s
# iter  866   |   diff: 3.00000   |   V(start): {'s
# iter  867   |   diff: 3.00000   |   V(start): {'s
# iter  868   |   diff: 3.00000   |   V(start): {'s
# iter  869   |   diff: 3.00000   |   V(start): {'s
# iter  870   |   diff: 3.00000   |   V(start): {'s
# iter  871   |   diff: 3.00000   |   V(start): {'s
# iter  872   |   diff: 3.00000   |   V(start): {'s
# iter  873   |   diff: 3.00000   |   V(start): {'s
# iter  874   |   diff: 3.00000   |   V(start): {'s
# iter  875   |   diff: 3.00000   |   V(start): {'s
# iter  876   |   diff: 3.00000   |   V(start): {'s
# iter  877   |   diff: 3.00000   |   V(start): {'s
# iter  878   |   diff: 3.00000   |   V(start): {'s
# iter  879   |   diff: 3.00000   |   V(start): {'s
# iter  880   |   diff: 3.00000   |   V(start): {'s
# iter  881   |   diff: 3.00000   |   V(start): {'s
# iter  882   |   diff: 3.00000   |   V(start): {'s
# iter  883   |   diff: 3.00000   |   V(start): {'s
# iter  884   |   diff: 3.00000   |   V(start): {'s
# iter  885   |   diff: 3.00000   |   V(start): {'s
# iter  886   |   diff: 3.00000   |   V(start): {'s
# iter  887   |   diff: 3.00000   |   V(start): {'s
# iter  888   |   diff: 3.00000   |   V(start): {'s
# iter  889   |   diff: 3.00000   |   V(start): {'s
# iter  890   |   diff: 3.00000   |   V(start): {'s
# iter  891   |   diff: 3.00000   |   V(start): {'s
# iter  892   |   diff: 3.00000   |   V(start): {'s
# iter  893   |   diff: 3.00000   |   V(start): {'s
# iter  894   |   diff: 3.00000   |   V(start): {'s
# iter  895   |   diff: 3.00000   |   V(start): {'s
# iter  896   |   diff: 3.00000   |   V(start): {'s
# iter  897   |   diff: 3.00000   |   V(start): {'s
# iter  898   |   diff: 3.00000   |   V(start): {'s
# iter  899   |   diff: 3.00000   |   V(start): {'s
# iter  900   |   diff: 3.00000   |   V(start): {'s
# iter  901   |   diff: 3.00000   |   V(start): {'s
# iter  902   |   diff: 3.00000   |   V(start): {'s
# iter  903   |   diff: 3.00000   |   V(start): {'s
# iter  904   |   diff: 3.00000   |   V(start): {'s
# iter  905   |   diff: 3.00000   |   V(start): {'s
# iter  906   |   diff: 3.00000   |   V(start): {'s
# iter  907   |   diff: 3.00000   |   V(start): {'s
# iter  908   |   diff: 3.00000   |   V(start): {'s
# iter  909   |   diff: 3.00000   |   V(start): {'s
# iter  910   |   diff: 3.00000   |   V(start): {'s
# iter  911   |   diff: 3.00000   |   V(start): {'s
# iter  912   |   diff: 3.00000   |   V(start): {'s
# iter  913   |   diff: 3.00000   |   V(start): {'s
# iter  914   |   diff: 3.00000   |   V(start): {'s
# iter  915   |   diff: 3.00000   |   V(start): {'s
# iter  916   |   diff: 3.00000   |   V(start): {'s
# iter  917   |   diff: 3.00000   |   V(start): {'s
# iter  918   |   diff: 3.00000   |   V(start): {'s
# iter  919   |   diff: 3.00000   |   V(start): {'s
# iter  920   |   diff: 3.00000   |   V(start): {'s
# iter  921   |   diff: 3.00000   |   V(start): {'s
# iter  922   |   diff: 3.00000   |   V(start): {'s
# iter  923   |   diff: 3.00000   |   V(start): {'s
# iter  924   |   diff: 3.00000   |   V(start): {'s
# iter  925   |   diff: 3.00000   |   V(start): {'s
# iter  926   |   diff: 3.00000   |   V(start): {'s
# iter  927   |   diff: 3.00000   |   V(start): {'s
# iter  928   |   diff: 3.00000   |   V(start): {'s
# iter  929   |   diff: 3.00000   |   V(start): {'s
# iter  930   |   diff: 3.00000   |   V(start): {'s
# iter  931   |   diff: 3.00000   |   V(start): {'s
# iter  932   |   diff: 3.00000   |   V(start): {'s
# iter  933   |   diff: 3.00000   |   V(start): {'s
# iter  934   |   diff: 3.00000   |   V(start): {'s
# iter  935   |   diff: 3.00000   |   V(start): {'s
# iter  936   |   diff: 3.00000   |   V(start): {'s
# iter  937   |   diff: 3.00000   |   V(start): {'s
# iter  938   |   diff: 3.00000   |   V(start): {'s
# iter  939   |   diff: 3.00000   |   V(start): {'s
# iter  940   |   diff: 3.00000   |   V(start): {'s
# iter  941   |   diff: 3.00000   |   V(start): {'s
# iter  942   |   diff: 3.00000   |   V(start): {'s
# iter  943   |   diff: 3.00000   |   V(start): {'s
# iter  944   |   diff: 3.00000   |   V(start): {'s
# iter  945   |   diff: 3.00000   |   V(start): {'s
# iter  946   |   diff: 3.00000   |   V(start): {'s
# iter  947   |   diff: 3.00000   |   V(start): {'s
# iter  948   |   diff: 3.00000   |   V(start): {'s
# iter  949   |   diff: 3.00000   |   V(start): {'s
# iter  950   |   diff: 3.00000   |   V(start): {'s
# iter  951   |   diff: 3.00000   |   V(start): {'s
# iter  952   |   diff: 3.00000   |   V(start): {'s
# iter  953   |   diff: 3.00000   |   V(start): {'s
# iter  954   |   diff: 3.00000   |   V(start): {'s
# iter  955   |   diff: 3.00000   |   V(start): {'s
# iter  956   |   diff: 3.00000   |   V(start): {'s
# iter  957   |   diff: 3.00000   |   V(start): {'s
# iter  958   |   diff: 3.00000   |   V(start): {'s
# iter  959   |   diff: 3.00000   |   V(start): {'s
# iter  960   |   diff: 3.00000   |   V(start): {'s
# iter  961   |   diff: 3.00000   |   V(start): {'s
# iter  962   |   diff: 3.00000   |   V(start): {'s
# iter  963   |   diff: 3.00000   |   V(start): {'s
# iter  964   |   diff: 3.00000   |   V(start): {'s
# iter  965   |   diff: 3.00000   |   V(start): {'s
# iter  966   |   diff: 3.00000   |   V(start): {'s
# iter  967   |   diff: 3.00000   |   V(start): {'s
# iter  968   |   diff: 3.00000   |   V(start): {'s
# iter  969   |   diff: 3.00000   |   V(start): {'s
# iter  970   |   diff: 3.00000   |   V(start): {'s
# iter  971   |   diff: 3.00000   |   V(start): {'s
# iter  972   |   diff: 3.00000   |   V(start): {'s
# iter  973   |   diff: 3.00000   |   V(start): {'s
# iter  974   |   diff: 3.00000   |   V(start): {'s
# iter  975   |   diff: 3.00000   |   V(start): {'s
# iter  976   |   diff: 3.00000   |   V(start): {'s
# iter  977   |   diff: 3.00000   |   V(start): {'s
# iter  978   |   diff: 3.00000   |   V(start): {'s
# iter  979   |   diff: 3.00000   |   V(start): {'s
# iter  980   |   diff: 3.00000   |   V(start): {'s
# iter  981   |   diff: 3.00000   |   V(start): {'s
# iter  982   |   diff: 3.00000   |   V(start): {'s
# iter  983   |   diff: 3.00000   |   V(start): {'s
# iter  984   |   diff: 3.00000   |   V(start): {'s
# iter  985   |   diff: 3.00000   |   V(start): {'s
# iter  986   |   diff: 3.00000   |   V(start): {'s
# iter  987   |   diff: 3.00000   |   V(start): {'s
# iter  988   |   diff: 3.00000   |   V(start): {'s
# iter  989   |   diff: 3.00000   |   V(start): {'s
# iter  990   |   diff: 3.00000   |   V(start): {'s
# iter  991   |   diff: 3.00000   |   V(start): {'s
# iter  992   |   diff: 3.00000   |   V(start): {'s
# iter  993   |   diff: 3.00000   |   V(start): {'s
# iter  994   |   diff: 3.00000   |   V(start): {'s
# iter  995   |   diff: 3.00000   |   V(start): {'s
# iter  996   |   diff: 3.00000   |   V(start): {'s
# iter  997   |   diff: 3.00000   |   V(start): {'s
# iter  998   |   diff: 3.00000   |   V(start): {'s
# iter  999   |   diff: 3.00000   |   V(start): {'s

# %%
# Measure agent's average reward

s = mdp.reset()
rewards = []
for _ in range(10000):
    s, r, done, _ = mdp.step(get_optimal_action(mdp, state_values, s, gamma))
    rewards.append(r)
    
print("average reward: ", np.mean(rewards))

assert(0.85 < np.mean(rewards) < 1.0)

# %% [markdown]
# __Your PI Results__

# %%
from mdp import FrozenLakeEnv
mdp = FrozenLakeEnv(slip_chance=0)

mdp.render()
state_values = policy_iteration(mdp)
# Out:
# *FFF
# FHFH
# FFFH
# HFFG
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-b05f5f1b0fdc> in <module>()
#       3
#       4 mdp.render()
# ----> 5 state_values = policy_iteration(mdp)
#
# <ipython-input-49-0a83a15d0841> in policy_iteration(mdp, policy, gamma, num_iter, min_difference)
#       6         policy = {s: get_rand_policy(s) for s in states}
#       7     for i in range(num_iter):
# ----> 8         new_vpi = compute_vpi(mdp, policy, gamma)
#       9         # Compute new state values using the functions you defined above. It must be a dict {state : new_V(state)}
#      10         new_policy = compute_new_policy(mdp, new_vpi, gamma)
#
# <ipython-input-27-b93cdc546a20> in compute_vpi(mdp, policy, gamma)
#      14         for j, next_state in enumerate(states):
#      15             b[i] = (
# ---> 16                 b[i] + mdp.get_transition_prob(state, policy[state], next_state) *
#      17                 (mdp.get_reward(state, policy[state], next_state))
#      18             )
#
# KeyError: (1, 1)

# %%
from mdp import FrozenLakeEnv
mdp = FrozenLakeEnv(slip_chance=0)

mdp.render()
# Out:
# *FFF
# FHFH
# FFFH
# HFFG

# %%
< Compare PI and VI on the MDP from bonus 1, then on small & large FrozenLake >
