# %% [markdown]
# ### Imagenet
#
# Largest image classification dataset at this point of time.
#
# Url: http://image-net.org/
#
# Our setup: classify from a set of 1000 classes.

# %%
доразобрать гуся: http://deeplearning.net/tutorial/lenet.html, features, filters, попробовать использовать неполную сеть или несколько слоев для извлечения фичей, с телефона

# %%
#https://www.mathworks.com/help/vision/examples/image-category-classification-using-deep-learning.html

# %%
#classes' names are stored here
import pickle
#открываем файл типа pickle, причем читаем биты; pickle используется для сжатия или быстроты обработки?
classes = pickle.load(open('E:\Фотки\Учеба\heh\DMIA\семы\тренды\sem4\classes.pkl','rb'))
print (classes[::100])
# Out:
# ['tench, Tinca tinca', 'black swan, Cygnus atratus', 'Tibetan terrier, chrysanthemum dog', 'tiger beetle', "academic gown, academic robe, judge's robe", 'cliff dwelling', 'hook, claw', 'paper towel', 'slot, one-armed bandit', 'water tower']

# %% [markdown]
# ### Using pre-trained model: inception
# Keras has a number of models for which you can use pre-trained weights. The interface is super-straightforward:

# %%
import tensorflow as tf
gpu_options = tf.GPUOptions(allow_growth=True, per_process_gpu_memory_fraction=0.1)
s = tf.InteractiveSession(config=tf.ConfigProto(gpu_options=gpu_options))

# %%
import keras
import keras.applications as zoo
#создаем модель с архитектурой Inception v3, загружает веса, претренированные на ImageNet; по умолчанию размер входного изобра-
#жения 299x299, 1000 классов и weights='imagenet', можно оставить None для рандомной инициализации; include_top - включать ли 
#fully-connected слой в верхней части сети(сначала идут слои свертки, сжимающие изображение, затем НЕ свертка, но как бы
#отдельная сеть, уже решающая, что на изображении(назовем ее fully-connected))
#https://medium.com/@ageitgey/machine-learning-is-fun-part-3-deep-learning-and-convolutional-neural-networks-f40359318721
model = zoo.InceptionV3(include_top=True, weights='imagenet')
# Out:
# Using TensorFlow backend.

# %%
len(model.layers)
# Out:
# 313

# %%
model.summary(110)    #расширяем таблицу в ширину, чтобы все вместилось
# Out:
# ______________________________________________________________________________________________________________
# Layer (type)                        Output Shape            Param #      Connected to
# ...
# input_1 (InputLayer)                (None, None, None, 3)   0
# ______________________________________________________________________________________________________________
# conv2d_1 (Conv2D)                   (None, None, None, 32)  864          input_1[0][0]
# ______________________________________________________________________________________________________________
# batch_normalization_1 (BatchNormali (None, None, None, 32)  96           conv2d_1[0][0]
# ______________________________________________________________________________________________________________
# activation_1 (Activation)           (None, None, None, 32)  0            batch_normalization_1[0][0]
# ______________________________________________________________________________________________________________
# ...

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))

# %%
conv_weigts_1 = model.get_layer(index=1).get_weights()[0]
conv_weigts_1
# Out:
# array([[[[ -4.59105551e-01,  -4.14526574e-02,  -3.62577499e-03,
#            -9.87672508e-02,  -3.37070860e-02,   4.79929037e-02,
#             2.32542142e-01,   3.23927671e-01,   5.90160079e-02,
#             9.47738215e-02,   4.24996056e-02,   1.26620471e-01,
#             1.33215979e-01,   1.22741833e-01,  -7.92686343e-02,
#             2.08227970e-02,  -1.99647829e-01,  -3.02687973e-01,
#            -2.10659921e-01,  -3.52898419e-01,  -5.58023095e-01,
#             3.20223093e-01,   4.53596050e-03,  -3.09266411e-02,
#            -6.86957911e-02,   2.00968519e-01,   1.14542745e-01,
#             2.40372881e-01,   1.52943470e-02,   5.96231259e-02,
#            -5.85714653e-02,   8.78173351e-01],
#          [  3.16376328e-01,  -4.78494260e-03,  -6.84681814e-03,
#             7.44503662e-02,  -1.97458476e-01,   5.20143658e-02,
#            -1.24460436e-01,   3.36123914e-01,   3.01678218e-02,
#            -1.26477107e-01,  -1.05597451e-01,  -5.31241074e-02,
# ...

# %%
conv_weigts_1.shape
# Out:
# (3, 3, 3, 32)

# %%
model.get_layer(index=1).data_format
# Out:
# 'channels_last'

# %%
'''from PIL import Image
arr = np.random.randint(0,256, 100*100) #example of a 1-D array
arr.resize((100,100))
im = Image.fromarray(arr)
im.show()'''
# Out:
# 'from PIL import Image\narr = np.random.randint(0,256, 100*100) #example of a 1-D array\narr.resize((100,100))\nim = Image.fromarray(arr)\nim.show()'

# %%
'''import numpy as np
import matplotlib.pyplot as plt

x = (np.random.rand(1754**2) < 0.5).astype(int)

im = x.reshape(1754, 1754)
#plt.gray()
plt.imshow(im)'''
# Out:
# 'import numpy as np\nimport matplotlib.pyplot as plt\n\nx = (np.random.rand(1754**2) < 0.5).astype(int)\n\nim = x.reshape(1754, 1754)\n#plt.gray()\nplt.imshow(im)'

# %% [markdown]
# ### Predict class probabilities

# %%
model = zoo.InceptionV3(include_top=True, weights='imagenet')
import matplotlib.pyplot as plt
from scipy.misc import imresize
# %matplotlib inline
#считываем изображение jpg в массив какого-то размера и затем переводим в другой размер (из 224x224 в 299x299, нужный для 
#входов сети)
img = imresize(plt.imread(r'E:\Фотки\Учеба\heh\DMIA\семы\тренды\sem4\sample_images/albatross.jpg'), (299,299))
plt.imshow(img)
plt.show()

img_preprocessed = zoo.inception_v3.preprocess_input(img[None].astype('float32'))
#вероятности принадлежности к каждому(из 1000) классу, массив размера 1x1000
probs = model.predict(img_preprocessed)
#ravel() сплющивает массив(до размерности 1)m argsort() возвращает индексы, сортирующие массив по возрастанию,берем 10 последних
labels = probs.ravel().argsort()[-1:-10:-1]
print ('top-10 classes are:')
for l in labels:
    #print ('%.4f\t%s' % (probs.ravel()[l], classes[l]))
    print ('%.4f\t%s' % (probs.ravel()[l], classes[l].split(',')[0]))
# Out:
# top-10 classes are:
# 0.9255	albatross
# 0.0017	turnstile
# 0.0008	drake
# 0.0005	collie
# 0.0005	Shetland sheepdog
# 0.0004	hammerhead
# 0.0004	nipple
# 0.0004	cello
# 0.0004	Polaroid camera

# %%
#img = imresize(plt.imread(r'E:\Фотки\Учеба\heh\DMIA\семы\тренды\sem4\sample_images/albatross.jpg'), (299,299))
img = plt.imread(r'E:\Фотки\Учеба\heh\DMIA\семы\тренды\sem4\sample_images/albatross.jpg')
print(img.shape)
#print(img)
img_preprocessed = zoo.inception_v3.preprocess_input(img[None].astype('float32'))
print(img_preprocessed.shape)
#print(img_preprocessed)
# Out:
# (224, 224, 3)
# (1, 224, 224, 3)

# %% [markdown]
# ### Having fun with pre-trained nets

# %%
#!wget http://cdn.com.do/wp-content/uploads/2017/02/Donal-Trum-Derogar.jpeg -O img.jpg

# %%
#!pip3 install python3-wget
#!pip3 install wget

# %%
import wget
#url = 'http://www.futurecrew.com/skaven/song_files/mp3/razorback.mp3'
#jpeg не читает?
#url = 'http://cdn.com.do/wp-content/uploads/2017/02/Donal-Trum-Derogar.jpeg'
url = 'https://timedotcom.files.wordpress.com/2015/01/trump.jpg'
#текующая директория :C\Пользователи\Владимир\Документы
filename = wget.download(url)
#filename = wget.download(url, bar=bar_thermometer)
# Out:
# 100% [........................................................] 430787 / 430787

# %%
#img = imresize(plt.imread('img.jpg'), (299,299))
img = imresize(plt.imread('trump.jpg'), (299,299))
plt.imshow(img)
plt.show()

img_preprocessed = zoo.inception_v3.preprocess_input(img[None].astype('float32'))

probs = model.predict(img_preprocessed)

labels = probs.ravel().argsort()[-1:-10:-1]
print ('top-10 classes are:')
for l in labels:
    print ('%.4f\t%s' % (probs.ravel()[l], classes[l].split(',')[0]))
# Out:
# top-10 classes are:
# 0.5842	suit
# 0.2306	Windsor tie
# 0.0308	groom
# 0.0056	bow tie
# 0.0046	wig
# 0.0036	notebook
# 0.0027	Loafer
# 0.0018	gown
# 0.0016	cornet

# %% [markdown]
# ### How do you reuse layers
#
# Since model is just a sequence of layers, one can apply it as any other Keras model. Then you can build more layers on top of it, train them and maybe fine-tune "body" weights a bit.

# %%
#Input = tf.placeholder('float32',[None,299,299,3])
#img = Input
#img = keras.backend.Input('float32',[None,299,299,3])
img = keras.layers.Input('float32',[None,299,299,3])

neck = zoo.InceptionV3(include_top=False, weights='imagenet')(img)

hid = keras.layers.GlobalMaxPool2D()(neck)

hid = keras.layers.Dense(512,activation='relu')(hid)

out = keras.layers.Dense(10,activation='softmax')(hid)

#model = keras.models.Model(inputs=img, outputs=out)
#<...> loss, training, etc.

# %%
model = zoo.InceptionV3(include_top=False, weights='imagenet')

# %%
model.summary(110)
# Out:
# ______________________________________________________________________________________________________________
# Layer (type)                        Output Shape            Param #      Connected to
# ...
# input_5 (InputLayer)                (None, None, None, 3)   0
# ______________________________________________________________________________________________________________
# conv2d_283 (Conv2D)                 (None, None, None, 32)  864          input_5[0][0]
# ______________________________________________________________________________________________________________
# batch_normalization_283 (BatchNorma (None, None, None, 32)  96           conv2d_283[0][0]
# ______________________________________________________________________________________________________________
# activation_283 (Activation)         (None, None, None, 32)  0            batch_normalization_283[0][0]
# ...

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))

# %%
len(model.layers)
# Out:
# 311

# %% [markdown]
# # Grand-quest: Dogs Vs Cats
# * original competition
# * https://www.kaggle.com/c/dogs-vs-cats
# * 25k JPEG images of various size, 2 classes (guess what)
#
# ### Your main objective
# * In this seminar your goal is to fine-tune a pre-trained model to distinguish between the two rivaling animals
# * The first step is to just reuse some network layer as features

# %%
#загрузить zip-файл, распаковать и удалить zip
'''#!wget https://www.dropbox.com/s/d61lupw909hc785/dogs_vs_cats.train.zip?dl=1 -O data.zip
#!unzip data.zip
url = 'https://www.dropbox.com/s/d61lupw909hc785/dogs_vs_cats.train.zip?dl=1'
filename = wget.download(url)
import zipfile
zip_ref = zipfile.ZipFile('dogs_vs_cats.train.zip', 'r')
zip_ref.extractall('E:\Фотки\Учеба\heh\DMIA\семы\тренды\dz4\dogs_vs_cats.train')
zip_ref.close()
import os
os.remove("dogs_vs_cats.train.zip")'''
# Out:
# '#!wget https://www.dropbox.com/s/d61lupw909hc785/dogs_vs_cats.train.zip?dl=1 -O data.zip\n#!unzip data.zip\nurl = \'https://www.dropbox.com/s/d61lupw909hc785/dogs_vs_cats.train.zip?dl=1\'\nfilename = wget.download(url)\nimport zipfile\nzip_ref = zipfile.ZipFile(\'dogs_vs_cats.train.zip\', \'r\')\nzip_ref.extractall(\'E:\\Фотки\\Учеба\\heh\\DMIA\\семы\\тренды\\dz4\\dogs_vs_cats.train\')\nzip_ref.close()\nimport os\nos.remove("dogs_vs_cats.train.zip")'

# %% [markdown]
# # for starters
# * Train sklearn model, evaluate validation accuracy (should be >80%

# %%
#все операции ниже можно делать с любой претренированной моделью?

# %%
#https://keras.io/applications/

# %%
#Extract features with VGG16, отсекаем последние слои, обученные на классификацию определенных классов картинок, получаем 
#сложные фичи произвольных картинок(чем больше слоев с конволюцией и пулингом тем сложнее фичи)
'''from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

model = VGG16(weights='imagenet', include_top=False)

img_path = r"E:\Фотки\Учеба\heh\DMIA\семы\тренды\dz4\dogs_vs_cats.train\train/cat.4.jpg"
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)    #размерность (224, 224, 3)
x = np.expand_dims(x, axis=0)    #размерность (1, 224, 224, 3)
#зачем строчка выше непонятно, так как в строчке ниже по наверное массив переводится в нужный размер, как уже делалось выше
x = preprocess_input(x)
#массив 4D должен подаваться на вход VGG16
features = model.predict(x)'''
# Out:
# 'from keras.applications.vgg16 import VGG16\nfrom keras.preprocessing import image\nfrom keras.applications.vgg16 import preprocess_input\nimport numpy as np\n\nmodel = VGG16(weights=\'imagenet\', include_top=False)\n\nimg_path = r"E:\\Фотки\\Учеба\\heh\\DMIA\\семы\\тренды\\dz4\\dogs_vs_cats.train\train/cat.4.jpg"\nimg = image.load_img(img_path, target_size=(224, 224))\nx = image.img_to_array(img)    #размерность (224, 224, 3)\nx = np.expand_dims(x, axis=0)    #размерность (1, 224, 224, 3)\n#зачем строчка выше непонятно, так как в строчке ниже по наверное массив переводится в нужный размер, как уже делалось выше\nx = preprocess_input(x)\n#массив 4D должен подаваться на вход VGG16\nfeatures = model.predict(x)'

# %%
#features
#features.shape

# %%
#моя попытка извлечения фичей из произвольного слоя
#попытка извлечения фичей из несколький первых(сверточного слоя)
'''model = zoo.InceptionV3(include_top=True, weights='imagenet')
inputs = keras.layers.Input('float32',[None,299,299,3])
#inputs = model.get_layer(index=0)
a = model.get_layer(index=1)(inputs)
outputs = model.get_layer(index=2)(a)
model = keras.models.Model(inputs=inputs, outputs=outputs)'''
# Out:
# "model = zoo.InceptionV3(include_top=True, weights='imagenet')\ninputs = keras.layers.Input('float32',[None,299,299,3])\n#inputs = model.get_layer(index=0)\na = model.get_layer(index=1)(inputs)\noutputs = model.get_layer(index=2)(a)\nmodel = keras.models.Model(inputs=inputs, outputs=outputs)"

# %%
'''import matplotlib.pyplot as plt
from scipy.misc import imresize
img = plt.imread(r'E:\Фотки\Учеба\heh\DMIA\семы\тренды\sem4\sample_images/albatross.jpg')
img = imresize(img,(299,299))
img = zoo.inception_v3.preprocess_input(img[None].astype('float32'))
features = model.predict(img)'''
# Out:
# "import matplotlib.pyplot as plt\nfrom scipy.misc import imresize\nimg = plt.imread(r'E:\\Фотки\\Учеба\\heh\\DMIA\\семы\\тренды\\sem4\\sample_images/albatross.jpg')\nimg = imresize(img,(299,299))\nimg = zoo.inception_v3.preprocess_input(img[None].astype('float32'))\nfeatures = model.predict(img)"

# %%
#features
#features.shape

# %%
#и нормальное извлечение: Extract features from an arbitrary intermediate layer with VGG19
'''from keras.applications.vgg19 import VGG19
from keras.preprocessing import image
from keras.applications.vgg19 import preprocess_input
from keras.models import Model
import numpy as np

base_model = VGG19(weights='imagenet')
model = Model(inputs=base_model.input, outputs=base_model.get_layer('block4_pool').output)

img_path = r"E:\Фотки\Учеба\heh\DMIA\семы\тренды\dz4\dogs_vs_cats.train\train/cat.5.jpg"
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

block4_pool_features = model.predict(x)'''
# Out:
# 'from keras.applications.vgg19 import VGG19\nfrom keras.preprocessing import image\nfrom keras.applications.vgg19 import preprocess_input\nfrom keras.models import Model\nimport numpy as np\n\nbase_model = VGG19(weights=\'imagenet\')\nmodel = Model(inputs=base_model.input, outputs=base_model.get_layer(\'block4_pool\').output)\n\nimg_path = r"E:\\Фотки\\Учеба\\heh\\DMIA\\семы\\тренды\\dz4\\dogs_vs_cats.train\train/cat.5.jpg"\nimg = image.load_img(img_path, target_size=(224, 224))\nx = image.img_to_array(img)\nx = np.expand_dims(x, axis=0)\nx = preprocess_input(x)\n\nblock4_pool_features = model.predict(x)'

# %%
#features
#block4_pool_features.shape

# %%
#Fine-tune InceptionV3 on a new set of classes
#топ не включаем, добавляем слои в конец(Dense слои), фиксируем веса из начальных слоев, тренируем веса только в этих последних 
#слоях; затем фиксируем веса из начальных слоев, кроме 2ух последних и добавленных и снова тренируем
'''from keras.applications.inception_v3 import InceptionV3
from keras.preprocessing import image
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from keras import backend as K

# create the base pre-trained model
base_model = InceptionV3(weights='imagenet', include_top=False)

# add a global spatial average pooling layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
x = Dense(1024, activation='relu')(x)
# and a logistic layer -- let's say we have 2 classes
predictions = Dense(2, activation='softmax')(x)

# this is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)

# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional InceptionV3 layers
for layer in base_model.layers:
    layer.trainable = False

# compile the model (should be done *after* setting layers to non-trainable)
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')

# train the model on the new data for a few epochs
model.fit_generator(...)

# at this point, the top layers are well trained and we can start fine-tuning
# convolutional layers from inception V3. We will freeze the bottom N layers
# and train the remaining top layers.

# let's visualize layer names and layer indices to see how many layers
# we should freeze:
for i, layer in enumerate(base_model.layers):
   print(i, layer.name)

# we chose to train the top 2 inception blocks, i.e. we will freeze
# the first 249 layers and unfreeze the rest:
for layer in model.layers[:249]:
   layer.trainable = False
for layer in model.layers[249:]:
   layer.trainable = True

# we need to recompile the model for these modifications to take effect
# we use SGD with a low learning rate
from keras.optimizers import SGD
model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), loss='categorical_crossentropy')

# we train our model again (this time fine-tuning the top 2 inception blocks
# alongside the top Dense layers
model.fit_generator(...)'''
# Out:
# "from keras.applications.inception_v3 import InceptionV3\nfrom keras.preprocessing import image\nfrom keras.models import Model\nfrom keras.layers import Dense, GlobalAveragePooling2D\nfrom keras import backend as K\n\n# create the base pre-trained model\nbase_model = InceptionV3(weights='imagenet', include_top=False)\n\n# add a global spatial average pooling layer\nx = base_model.output\nx = GlobalAveragePooling2D()(x)\n# let's add a fully-connected layer\nx = Dense(1024, activation='relu')(x)\n# and a logistic layer -- let's say we have 2 classes\npredictions = Dense(2, activation='softmax')(x)\n\n# this is the model we will train\nmodel = Model(inputs=base_model.input, outputs=predictions)\n\n# first: train only the top layers (which were randomly initialized)\n# i.e. freeze all convolutional InceptionV3 layers\nfor layer in base_model.layers:\n    layer.trainable = False\n\n# compile the model (should be done *after* setting layers to non-trainable)\nmodel.compile(optimizer='rmsp
# ...

# %%
#Build InceptionV3 over a custom input tensor
#можно менять входную размерность
'''from keras.applications.inception_v3 import InceptionV3
from keras.layers import Input

# this could also be the output a different Keras model or layer
input_tensor = Input(shape=(224, 224, 3))  # this assumes K.image_data_format() == 'channels_last'

model = InceptionV3(input_tensor=input_tensor, weights='imagenet', include_top=True)'''
# Out:
# "from keras.applications.inception_v3 import InceptionV3\nfrom keras.layers import Input\n\n# this could also be the output a different Keras model or layer\ninput_tensor = Input(shape=(224, 224, 3))  # this assumes K.image_data_format() == 'channels_last'\n\nmodel = InceptionV3(input_tensor=input_tensor, weights='imagenet', include_top=True)"

# %%
#аргументы моделей
#1)include_top: whether to include the fully-connected layers at the top of the network
#2)weights: one of None (random initialization) or 'imagenet' (pre-training on ImageNet)
#3)input_tensor: optional Keras tensor (i.e. output of layers.Input()) to use as image input for the model
#4)input_shape: optional shape tuple, only to be specified if include_top is False (otherwise the input shape has to be  
#(299, 299, 3). It should have exactly 3 inputs channels, and width and height should be no smaller than 71. E.g.  (150, 150, 3) 
#would be one valid value
#т.е. можно менять размерность, если не включать плотные слои
#5)pooling: Optional pooling mode for feature extraction when include_top is False.
#None means that the output of the model will be the 4D tensor output of the last convolutional layer.
#'avg' means that global average pooling will be applied to the output of the last convolutional layer, and thus the output of the model will be a 2D tensor.
#'max' means that global max pooling will be applied
#т.е. иожно применить пулинг к аутпуту модели, если не включать плотные слои
#6)classes: optional number of classes to classify images into, only to be specified if include_top is True, and if no weights 
#argument is specified

# %%
#Итак,

# %%
#не хватает памяти, чтобы все записать в один массив X
'''
IMAGE_W = 250
model = zoo.InceptionV3(input_shape=(IMAGE_W, IMAGE_W, 3), pooling='avg', include_top=False, weights='imagenet')
#extract features from images
from tqdm import tqdm    #для табличек прогресса
from scipy.misc import imresize
import os
X = []
Y = []

#this may be a tedious process. If so, store the results in some pickle and re-use them.
#os.listdir возвращает список имен файлов в директории
for fname in tqdm(os.listdir(r'E:\Фотки\Учеба\heh\DMIA\семы\тренды\dz4\dogs_vs_cats.train\train/')):
    y = fname.startswith("cat")
    img = plt.imread(r"E:\Фотки\Учеба\heh\DMIA\семы\тренды\dz4\dogs_vs_cats.train\train/"+fname)
    img = imresize(img,(IMAGE_W, IMAGE_W))
    img = zoo.inception_v3.preprocess_input(img[None].astype('float32'))
    
    #features = <use network to process the image into features>
    features = model.predict(img)
    Y.append(y)
    X.append(features)'''
# Out:
# '#extract features from images\nfrom tqdm import tqdm    #для табличек прогресса\nfrom scipy.misc import imresize\nimport os\nIMAGE_W = 250\nX = []\nY = []\n\n#this may be a tedious process. If so, store the results in some pickle and re-use them.\n#os.listdir возвращает список имен файлов в директории\nfor fname in tqdm(os.listdir(r\'E:\\Фотки\\Учеба\\heh\\DMIA\\семы\\тренды\\dz4\\dogs_vs_cats.train\train/\')):\n    y = fname.startswith("cat")\n    img = plt.imread(r"E:\\Фотки\\Учеба\\heh\\DMIA\\семы\\тренды\\dz4\\dogs_vs_cats.train\train/"+fname)\n    img = imresize(img,(IMAGE_W,IMAGE_W))\n    img = zoo.inception_v3.preprocess_input(img[None].astype(\'float32\'))\n    \n    #features = <use network to process the image into features>\n    features = model.predict(img)\n    Y.append(y)\n    X.append(features)'

# %%
#поэтому сначала сохраним сначала сохраним фичи каждой картинки в файл features_pooling.pkl, чтобы каждый раз их не 
#пересчитывать, а потом достанем их оттуда
'''
IMAGE_W = 250
model = zoo.InceptionV3(input_shape=(IMAGE_W ,IMAGE_W, 3), pooling='avg', include_top=False, weights='imagenet')
#extract features from images
from tqdm import tqdm    #для табличек прогресса
from scipy.misc import imresize
import os
X = []
Y = []
f = open(r'E:\Фотки\Учеба\heh\DMIA\семы\тренды\dz4\features_pooling.pkl', 'wb')

#this may be a tedious process. If so, store the results in some pickle and re-use them.
#os.listdir возвращает список имен файлов в директории
for fname in tqdm(os.listdir(r'E:\Фотки\Учеба\heh\DMIA\семы\тренды\dz4\dogs_vs_cats.train\train/')):
    y = fname.startswith("cat")
    img = plt.imread(r"E:\Фотки\Учеба\heh\DMIA\семы\тренды\dz4\dogs_vs_cats.train\train/"+fname)
    img = imresize(img,(IMAGE_W, IMAGE_W))
    img = zoo.inception_v3.preprocess_input(img[None].astype('float32'))
    
    #features = <use network to process the image into features>
    features = model.predict(img)
    pickle.dump(features, f)
    Y.append(y)
    #X.append(features)
f.close()'''
# Out:
# 'from tqdm import tqdm    #для табличек прогресса\nfrom scipy.misc import imresize\nimport os\nIMAGE_W = 250\nX = []\nY = []\nf = open(r\'E:\\Фотки\\Учеба\\heh\\DMIA\\семы\\тренды\\dz4\x0ceatures_pooling.pkl\', \'wb\')\n\n#this may be a tedious process. If so, store the results in some pickle and re-use them.\n#os.listdir возвращает список имен файлов в директории\nfor fname in tqdm(os.listdir(r\'E:\\Фотки\\Учеба\\heh\\DMIA\\семы\\тренды\\dz4\\dogs_vs_cats.train\train/\')):\n    y = fname.startswith("cat")\n    img = plt.imread(r"E:\\Фотки\\Учеба\\heh\\DMIA\\семы\\тренды\\dz4\\dogs_vs_cats.train\train/"+fname)\n    img = imresize(img,(IMAGE_W,IMAGE_W))\n    img = zoo.inception_v3.preprocess_input(img[None].astype(\'float32\'))\n    \n    #features = <use network to process the image into features>\n    features = model.predict(img)\n    pickle.dump(features, f)\n    Y.append(y)\n    #X.append(features)\nf.close()'

# %%
f = open(r'E:\Фотки\Учеба\heh\DMIA\семы\тренды\dz4\features_pooling.pkl', 'rb')
data_new = pickle.load(f)

# %%
import numpy as np
np.array(data_new).shape
# Out:
# (1, 2048)

# %%
#после сохранения в файл, каждый раз нужно теперь только заполнять Y
import matplotlib.pyplot as plt
from scipy.misc import imresize
#extract features from images
from tqdm import tqdm    #для табличек прогресса
from scipy.misc import imresize
import os
Y = []

#this may be a tedious process. If so, store the results in some pickle and re-use them.
#os.listdir возвращает список имен файлов в директории
for fname in tqdm(os.listdir(r'E:\Фотки\Учеба\heh\DMIA\семы\тренды\dz4\dogs_vs_cats.train\train/')):
    y = fname.startswith("cat")
    Y.append(y)
# Out:
# 100%|████████████████████████████████| 25000/25000 [00:00<00:00, 999386.21it/s]

# %%
#значение True(1), если кошка, False(0), если собака
Y[12300] - 1
# Out:
# 0

# %%
X = []
f = open(r'E:\Фотки\Учеба\heh\DMIA\семы\тренды\dz4\features_pooling.pkl', 'rb')
for i in range(25000):
    X.append(pickle.load(f))

# %%
X[1].shape
# Out:
# (1, 2048)

# %%
import numpy as np
X = np.concatenate(X) #stack all [1xfeatures] matrices into one. 
assert X.ndim==2
#WARNING! the concatenate works for [1xN] matrices. If you have other format, stack them yourself.

#crop if we ended prematurely
Y = Y[:len(X)]

# %%
len(Y)
# Out:
# 25000

# %%
X
# Out:
# array([[ 0.26397508,  0.32069215,  0.24254102, ...,  1.80152833,
#          1.10254097,  0.75411636],
#        [ 0.00644653,  0.06373981,  0.10116614, ...,  0.78278577,
#          1.13619626,  0.09045158],
#        [ 0.15315177,  0.12848428,  0.15065216, ...,  1.24210131,
#          1.0169493 ,  0.28877333],
#        ...,
#        [ 0.11063758,  0.57579637,  0.04767751, ...,  0.37366185,
#          0.27083457,  0.13442852],
#        [ 0.78455353,  0.1225383 ,  0.19180086, ...,  0.62989169,
#          0.92861015,  0.72065955],
#        [ 0.77280784,  0.73186529,  0.09758484, ...,  1.26224828,
#          2.17029572,  0.10404453]], dtype=float32)

# %%
#<split data either here or use cross-validation>
Y = keras.utils.to_categorical(Y, 2)
print('Y shape:', Y.shape)
# Out:
# Y shape: (25000, 2)

# %%
#Y[12499]
Y[12500]
# Out:
# array([ 1.,  0.])

# %%
#одинаково перемешаем массивы
np.random.seed(42)
k = [1, 2, 3, 4, 5, 6]
np.random.shuffle(X)
np.random.seed(42)
m = [6, 5, 4, 3, 2, 1]
np.random.shuffle(Y)

# %%
Y_test = Y[:20000]
Y_train = Y[20000:]
X_test = X[:20000]
X_train = X[20000:]

# %% [markdown]
# __load our dakka__
# ![img](https://s-media-cache-ak0.pinimg.com/564x/80/a1/81/80a1817a928744a934a7d32e7c03b242.jpg)

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier,GradientBoostingClassifier,AdaBoostClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Main quest
#
# * Get the score improved!
# * You have to reach __at least 95%__ on the test set. More = better.
#
# No methods are illegal: ensembling, data augmentation, NN hacks.
# Just don't let test data slip into training.
#
#
# ### Split the raw image data
#   * please do train/validation/test instead of just train/test
#   * reasonable but not optimal split is 20k/2.5k/2.5k or 15k/5k/5k
#
# ### Choose which vgg layers are you going to use
#   * Anything but for prob is okay
#   * Do not forget that vgg16 uses dropout
#
# ### Build a few layers on top of chosen "neck" layers.
#   * a good idea is to just stack more layers inside the same network
#   * alternative: stack on top of get_output
#
# ### Train the newly added layers for some iterations
#   * you can selectively train some weights by setting var_list in the optimizer
#       * `opt = tf.train.AdamOptimizer(learning_rate=...)`
#       * `updates = opt.minimize(loss,var_list=variables_you_wanna_train)`
#   * it's cruicial to monitor the network performance at this and following steps
#
# ### Fine-tune the network body
#   * probably a good idea to SAVE your new network weights now 'cuz it's easy to mess things up.
#   * Moreover, saving weights periodically is a no-nonsense idea
#   * even more cruicial to monitor validation performance
#   * main network body may need a separate, much lower learning rate
#       * you can create two update operations
#       * `opt1 = tf.train.AdamOptimizer(learning_rate=lr1)`
#       * `updates1 = opt1.minimize(loss,var_list=head_weights)`
#       * `opt2 = tf.train.AdamOptimizer(learning_rate=lr2)`
#       * `updates2 = opt2.minimize(loss,var_list=body_weights)`
#       * `s.run([updates1,updates2],{...})
#
# ### Grading
# * 95% accuracy on test yields 10 points
# * -1 point per 5% less accuracy
#
# ### Some ways to get bonus points
# * explore other networks from the model zoo
# * play with architecture
# * 96%/97%/98%/99%/99.5% test score (screen pls).
# * data augmentation, prediction-time data augmentation
# * use any more advanced fine-tuning technique you know/read anywhere
# * ml hacks that benefit the final score

# %%
#<A whole lot of your code>

# %%
#из сема 1

# %%
from keras.layers import Dense, Dropout, Activation, Input
from keras.models import Sequential, Model
a = Input(shape=(2048,))    #2048-размерность вектора фичей
b = Dense(512)(a)
b = Activation('relu')(b)
b = Dropout(0.8)(b)
b = Dense(2)(b)    #2 класса всего
b = Activation('softmax')(b)
model = Model(inputs=a, outputs=b)

# %%
from keras.objectives import categorical_crossentropy
from keras import backend as K

epsilon = 1.0e-9
def custom_objective(y_true, y_pred):
    '''Yet another crossentropy'''
    y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)   
#обрезаем значения меньше epsilon и больше 1.0 - epsilon(на выходе нейросети получили вектор "вероятностей" с помощью фукнции
#активации softmax,каждое значение от 0 до 1 теоретически и,чтобы не подставлять 0 в логарифм в функции кроссэнтропии, обрезаем)
    y_pred /= K.sum(y_pred, axis=-1, keepdims=True)    #нормировка после обрезания?
    cce = categorical_crossentropy(y_pred, y_true)
    return cce

# %%
model.compile(loss=custom_objective,
              optimizer='adam',
              metrics=['accuracy'])

# %%
batch_size = 32
epochs = 5

from keras.callbacks import EarlyStopping  
early_stopping=EarlyStopping(monitor='val_loss')    
#stop training when a monitored quantity has stopped improving
#смотрим на val_loss - validation loss

history = model.fit(X_train, Y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_split=0.1,
                    callbacks=[early_stopping])    #list of callbacks to apply during training
# Out:
# Train on 4500 samples, validate on 500 samples
# Epoch 1/5
# ...

# %%
score = model.evaluate(X_test, Y_test,
                       batch_size=batch_size, verbose=1)
#evaluate() returns scalar test loss (if the model has no metrics) or list of scalars (if the model computes other metrics)
print('\n')
print('Test score:', score[0])    #scalar test loss
print('Test accuracy:', score[1])    #первая(и единственная в нашем случае) добавленная доп метрика metrics=['accuracy']
# Out:
# 20000/20000 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 2s 121us/step
#
#
# Test score: 0.183737315359
# Test accuracy: 0.98855

# %%
print('Test score:', score[0])    #scalar test loss
print('Test accuracy:', score[1])    #первая(и единственная в нашем случае) добавленная доп метрика metrics=['accuracy']
# Out:
# Test score: 0.183737315359
# Test accuracy: 0.98855

# %%
IMAGE_W = 250
model_basic = zoo.InceptionV3(input_shape=(IMAGE_W, IMAGE_W, 3), pooling='avg', include_top=False, weights='imagenet')

# %%
img = plt.imread(r"E:\Фотки\Учеба\heh\DMIA\семы\тренды\dz4\dogs_vs_cats.train\train/dog.651.jpg")
#651ый пес похож на кошку
#img = plt.imread(r"E:\Фотки\Учеба\heh\DMIA\семы\тренды\dz4\dogs_vs_cats.train\train/cat.2323.jpg")
img = imresize(img,(IMAGE_W, IMAGE_W))
img = zoo.inception_v3.preprocess_input(img[None].astype('float32'))
features = model_basic.predict(img)
model.predict(features)
# Out:
# array([[  1.99886883e-04,   9.99800146e-01]], dtype=float32)

# %%
#1)можно было сразу объединить эти 2 сети, добавив слоев к первой базовой, и тренируя веса только из этих слоев
#2)использовать другие претренированные модели(например, vgg)
#3)использовать меньше базовых
#4)изменить структуру добавленных слоев(например, не использовать дропаут)
#5)

# %%
help(model)
# Out:
# Help on Model in module keras.engine.training object:
#
# class Model(keras.engine.topology.Container)
#  |  The `Model` class adds training & evaluation routines to a `Container`.
#  |
#  |  Method resolution order:
#  |      Model
#  |      keras.engine.topology.Container
#  |      keras.engine.topology.Layer
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  compile(self, optimizer, loss, metrics=None, loss_weights=None, sample_weight_mode=None, weighted_metrics=None, target_tensors=None, **kwargs)
#  |      Configures the model for training.
#  |
#  |      # Arguments
#  |          optimizer: String (name of optimizer) or optimizer instance.
#  |              See [optimizers](/optimizers).
#  |          loss: String (name of objective function) or objective function.
#  |              See [losses](/losses).
#  |              If the model has multiple outputs, you can use a different loss
# ...

# %%
#некоторые полезные фишки для обработки картинок, извлечение простейших фичей без использования сетей:

# %%
#-------------------------------------------------
from PIL import Image
# %matplotlib inline
image = Image.open('trump.jpg')
image

# %%
#преобразование из цветной в черно-белую картинку
im = image.convert('L')
im

# %%
#преобразование из черно-белой в массив
import numpy as np
im_array = np.array(im)
im_array

# %%
im_array.shape

# %%
im_array.flatten().shape

# %%
from pylab import *
figure()
gray()
contour(im, origin='image')
axis('equal')
axis('off')
figure()
hist(im_array.flatten(), 128)
show()

# %%
from PIL import *
figure()
p = image.convert('L').filter(ImageFilter.GaussianBlur(radius=2))
p.show()

# %%
#-------------------------------------------------
#http://deeplearning.net/tutorial/lenet.html
#!pip3 install theano
import theano
from theano import tensor as T
from theano.tensor.nnet import conv2d

import numpy

rng = numpy.random.RandomState(23455)

# instantiate 4D tensor for input
input = T.tensor4(name='input')

# initialize shared variable for weights.
w_shp = (2, 3, 9, 9)
w_bound = numpy.sqrt(3 * 9 * 9)
W = theano.shared( numpy.asarray(
            rng.uniform(
                low=-1.0 / w_bound,
                high=1.0 / w_bound,
                size=w_shp),
            dtype=input.dtype), name ='W')

# initialize shared variable for bias (1D tensor) with random values
# IMPORTANT: biases are usually initialized to zero. However in this
# particular application, we simply apply the convolutional layer to
# an image without learning the parameters. We therefore initialize
# them to random values to "simulate" learning.
b_shp = (2,)
b = theano.shared(numpy.asarray(
            rng.uniform(low=-.5, high=.5, size=b_shp),
            dtype=input.dtype), name ='b')

# build symbolic expression that computes the convolution of input with filters in w
conv_out = conv2d(input, W)

# build symbolic expression to add bias and apply activation function, i.e. produce neural net layer output
# A few words on ``dimshuffle`` :
#   ``dimshuffle`` is a powerful tool in reshaping a tensor;
#   what it allows you to do is to shuffle dimension around
#   but also to insert new ones along which the tensor will be
#   broadcastable;
#   dimshuffle('x', 2, 'x', 0, 1)
#   This will work on 3d tensors with no broadcastable
#   dimensions. The first dimension will be broadcastable,
#   then we will have the third dimension of the input tensor as
#   the second of the resulting tensor, etc. If the tensor has
#   shape (20, 30, 40), the resulting tensor will have dimensions
#   (1, 40, 1, 20, 30). (AxBxC tensor is mapped to 1xCx1xAxB tensor)
#   More examples:
#    dimshuffle('x') -> make a 0d (scalar) into a 1d vector
#    dimshuffle(0, 1) -> identity
#    dimshuffle(1, 0) -> inverts the first and second dimensions
#    dimshuffle('x', 0) -> make a row out of a 1d vector (N to 1xN)
#    dimshuffle(0, 'x') -> make a column out of a 1d vector (N to Nx1)
#    dimshuffle(2, 0, 1) -> AxBxC to CxAxB
#    dimshuffle(0, 'x', 1) -> AxB to Ax1xB
#    dimshuffle(1, 'x', 0) -> AxB to Bx1xA
output = T.nnet.sigmoid(conv_out + b.dimshuffle('x', 0, 'x', 'x'))

# create theano function to compute filtered images
f = theano.function([input], output)

# %%
import numpy
import pylab
from PIL import Image

# open random image of dimensions 639x516
img = Image.open('E:\Фотки\Учеба\heh\DMIA\семы\тренды\sem4\sample_images/albatross.jpg')
# dimensions are (height, width, channel)
img = numpy.asarray(img, dtype='float64') / 256.
print(img.shape)

# put image in 4D tensor of shape (1, 3, height, width)
img_ = img.transpose(2, 0, 1).reshape(1, 3, 224, 224)
filtered_img = f(img_)

# plot original image and first and second components of output
pylab.subplot(1, 3, 1); pylab.axis('off'); pylab.imshow(img)
pylab.gray();
# recall that the convOp output (filtered image) is actually a "minibatch",
# of size 1 here, so we take index 0 in the first dimension:
pylab.subplot(1, 3, 2); pylab.axis('off'); pylab.imshow(filtered_img[0, 0, :, :])
pylab.subplot(1, 3, 3); pylab.axis('off'); pylab.imshow(filtered_img[0, 1, :, :])
pylab.show()

# %%
#-------------------------------------------------
#выделение краев у черно-белой картинки
#! pip3 install scikit-image
from skimage import feature, color, data, io, filters
#from skimage.morphology import disk
image = data.coins()
#image = data.camera()    #и т.д.
edges = filters.sobel(image)
#edges = feature.canny(image)
#edges = filters.rank.median(image, disk(5))
#edges = filters.gaussian(image, 1)    #тоже гауссовский фильтр
io.imshow(edges)
io.show()

# %%
#-------------------------------------------------
#https://peerj.com/articles/453/
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# Load a small section of the image.
image = data.coins()[0:95, 70:370]

fig, axes = plt.subplots(ncols=2, nrows=3,
                         figsize=(8, 4))
ax0, ax1, ax2, ax3, ax4, ax5  = axes.flat
ax0.imshow(image, cmap=plt.cm.gray)
ax0.set_title('Original', fontsize=12)
ax0.axis('off')

# Histogram.
values, bins = np.histogram(image,
                            bins=np.arange(256))

ax1.plot(bins[:-1], values, lw=2, c='k')    #c='k' - черный цвет
ax1.set_xlim(xmax=256)
ax1.set_yticks([0, 400])
ax1.set_aspect(.2)
ax1.set_title('Histogram', fontsize=12)

# Apply threshold.
from skimage.filters import threshold_adaptive

bw = threshold_adaptive(image, 95, offset=-15)

ax2.imshow(bw, cmap=plt.cm.gray)
ax2.set_title('Adaptive threshold', fontsize=12)
ax2.axis('off')

# Find maxima.
from skimage.feature import peak_local_max

coordinates = peak_local_max(image, min_distance=20)

ax3.imshow(image, cmap=plt.cm.gray)
ax3.autoscale(False)
ax3.plot(coordinates[:, 1],
         coordinates[:, 0], c='r')
        #c='r.' работает, если рисовать отдельно этот график Peak local maxima
ax3.set_title('Peak local maxima', fontsize=12)
ax3.axis('off')

# Detect edges.
from skimage import filters
edges = filters.canny(image, sigma=3,
#edges = skimage.feature.canny(image, sigma=3,
                     low_threshold=10,
                     high_threshold=80)

ax4.imshow(edges, cmap=plt.cm.gray)
ax4.set_title('Edges', fontsize=12)
ax4.axis('off')

# Label image regions.
from skimage.measure import regionprops
import matplotlib.patches as mpatches
from skimage.morphology import label

label_image = label(edges)

ax5.imshow(image, cmap=plt.cm.gray)
ax5.set_title('Labeled items', fontsize=12)
ax5.axis('off')

for region in regionprops(label_image):
    # Draw rectangle around segmented coins.
    minr, minc, maxr, maxc = region.bbox
    rect = mpatches.Rectangle((minc, minr),
                              maxc - minc,
                              maxr - minr,
                              fill=False,
                              edgecolor='red',
                              linewidth=2)
    ax5.add_patch(rect)

plt.tight_layout()
plt.show()

# %%
#еще библиотеки
#from skimage import measure, restoration
#image = data.coins()
#find_contours = measure.find_contours(image, 5)

# %%
#гауссовский фильтр для RGB картинок
from skimage.data import astronaut
image = astronaut()
filtered_img = filters.gaussian(image, sigma=3, multichannel=True)
io.imshow(filtered_img)
io.show()

# %%
image = Image.open('trump.jpg')
im = image.convert('L')
im_array = np.array(im)
edges = filters.sobel(im_array)
io.imshow(edges)
io.show()
